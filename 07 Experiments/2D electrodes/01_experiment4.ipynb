# %% [markdown]
# #### Experiment 4a
# - 2D
# - Linear variation - electrode exponents vary from -1 to -2
# - 25 electrodes
# - Aperiodic noise only
# - Average by TS, PSD and SpecMod. Do not produce plots, save outputs
# - Load in JSON output summaries and plot a single combined plot

# %%
# Imports for functionality 
from dissertation_simulations.time_series import sweep_electrodes_ts_2D
from dissertation_simulations.psd import sweep_electrodes_psd_2D
from dissertation_simulations.spec_mod import sweep_electrodes_specmod_2D
from dissertation_simulations.exponents import generate_spatial_exponent_matrix, generate_2D_exponent_matrix
from dissertation_simulations.plotting import plot_summary_boxplots

import numpy as np
import json

from scipy.stats import ttest_rel

# %%
# Define exponent matrix
exp_matrix = generate_2D_exponent_matrix(grid_shape=(5, 5), exp_range=(-2, -1), gradient_axis="cols")
exp_matrix
# Out:
# array([[-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ]])

# %%
# Average the time series
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_ts_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp4a_result1_ts = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4aresults1_ts_exp_matrix_cols_-1-2.json", "w") as f:
    json.dump(exp4a_result1_ts, f, indent=4)

# Average the PSD
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp4a_result2_psd = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4aresults2_psd_exp_matrix_cols_-1-2.json", "w") as f:
    json.dump(exp4a_result2_psd, f, indent=4)

# Average the SpecMod
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_specmod_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp4a_result3_specmod = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4aresults3_specmod_exp_matrix_cols_-1-2.json", "w") as f:
    json.dump(exp4a_result3_specmod, f, indent=4)

# Loading summaries and combining into a single plot
summary_paths = [
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4aresults1_ts_exp_matrix_cols_-1-2.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4aresults2_psd_exp_matrix_cols_-1-2.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4aresults3_specmod_exp_matrix_cols_-1-2.json"
]

labels = [
    "Average time series",
    "Average PSD",
    "Average spectral model"
]

fig, ax = plot_summary_boxplots(
    summary_paths=summary_paths,
    labels=labels,
    true_mean_exp=np.mean(-exp_matrix)
)

fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\Combined plots\exp4a_combined_plot_2D_exp_matrix_cols_-1-2.png", dpi=300, bbox_inches="tight")

# %%
# Paired t-tests
with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4aresults1_ts_exp_matrix_cols_-1-2.json") as f:
    ts_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4aresults2_psd_exp_matrix_cols_-1-2.json") as f:
    psd_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4aresults3_specmod_exp_matrix_cols_-1-2.json") as f:
    spec_data = json.load(f)

ts = np.array(ts_data["all_distributions"][0])
psd = np.array(psd_data["all_distributions"][0])
spec = np.array(spec_data["all_distributions"][0])

t, p = ttest_rel(ts, psd)
print(f"Time series vs PSD: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(ts, spec)
print(f"Time series vs Spectral model: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd, spec)
print(f"PSD vs Spectral model: t = {t:.3f}, p = {p:.5f}")
# Out:
# Time series vs PSD: t = 3.719, p = 0.00033
# Time series vs Spectral model: t = -15.129, p = 0.00000
# PSD vs Spectral model: t = -52.095, p = 0.00000

# %% [markdown]
# #### Experiment 4b
# - 2D
# - Linear variation - electrode exponents vary from -1 to -1.5 - "middle out"
# - 25 electrodes
# - Aperiodic noise only
# - Average by TS, PSD and SpecMod. Do not produce plots, save outputs
# - Load in JSON output summaries and plot a single combined plot

# %%
# Define exponent matrix
exp_matrix = generate_spatial_exponent_matrix(grid_shape=(5, 5), exp_min=-1.5, exp_max=-1, pattern="middle")
exp_matrix
# Out:
# array([[-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ]])

# %%
# Average the time series
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_ts_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp4b_result1_ts = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4bresults1_ts_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp4b_result1_ts, f, indent=4)

# Average the PSD
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp4b_result2_psd = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4bresults2_psd_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp4b_result2_psd, f, indent=4)

# Average the SpecMod
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_specmod_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp4b_result3_specmod = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4bresults3_specmod_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp4b_result3_specmod, f, indent=4)

# Loading summaries and combining into a single plot
summary_paths = [
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4bresults1_ts_exp_matrix_middle_-1-1.5.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4bresults2_psd_exp_matrix_middle_-1-1.5.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4bresults3_specmod_exp_matrix_middle_-1-1.5.json"
]

labels = [
    "Average time series",
    "Average PSD",
    "Average spectral model"
]

fig, ax = plot_summary_boxplots(
    summary_paths=summary_paths,
    labels=labels,
    true_mean_exp=np.mean(-exp_matrix)
)

fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\Combined plots\exp4b_combined_plot_2D_exp_matrix_middle_-1-1.5.png", dpi=300, bbox_inches="tight")

# %%
# Paired t-tests
with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4bresults1_ts_exp_matrix_middle_-1-1.5.json") as f:
    ts_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4bresults2_psd_exp_matrix_middle_-1-1.5.json") as f:
    psd_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4bresults3_specmod_exp_matrix_middle_-1-1.5.json") as f:
    spec_data = json.load(f)

ts = np.array(ts_data["all_distributions"][0])
psd = np.array(psd_data["all_distributions"][0])
spec = np.array(spec_data["all_distributions"][0])

t, p = ttest_rel(ts, psd)
print(f"Time series vs PSD: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(ts, spec)
print(f"Time series vs Spectral model: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd, spec)
print(f"PSD vs Spectral model: t = {t:.3f}, p = {p:.5f}")
# Out:
# Time series vs PSD: t = 1.887, p = 0.06210
# Time series vs Spectral model: t = -2.692, p = 0.00835
# PSD vs Spectral model: t = -17.885, p = 0.00000

# %% [markdown]
# #### Experiment 4c
# - 2D
# - Linear variation - electrode exponents vary from -1 to -1.5 - "middle in"
# - 25 electrodes
# - Aperiodic noise only
# - Average by TS, PSD and SpecMod. Do not produce plots, save outputs
# - Load in JSON output summaries and plot a single combined plot

# %%
# Define exponent matrix
exp_matrix = generate_spatial_exponent_matrix(grid_shape=(5, 5), exp_min=-1, exp_max=-1.5, pattern="middle")
exp_matrix
# Out:
# array([[-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ]])

# %%
# Average the time series
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_ts_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp4c_result1_ts = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4cresults1_ts_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp4c_result1_ts, f, indent=4)

# Average the PSD
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp4c_result2_psd = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4cresults2_psd_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp4c_result2_psd, f, indent=4)

# Average the SpecMod
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_specmod_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp4c_result3_specmod = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4cresults3_specmod_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp4c_result3_specmod, f, indent=4)

# Loading summaries and combining into a single plot
summary_paths = [
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4cresults1_ts_exp_matrix_middle_-1-1.5.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4cresults2_psd_exp_matrix_middle_-1-1.5.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4cresults3_specmod_exp_matrix_middle_-1-1.5.json"
]

labels = [
    "Average time series",
    "Average PSD",
    "Average spectral model"
]

fig, ax = plot_summary_boxplots(
    summary_paths=summary_paths,
    labels=labels,
    true_mean_exp=np.mean(-exp_matrix)
)

fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\Combined plots\exp4c_combined_plot_2D_exp_matrix_middle_-1-1.5.png", dpi=300, bbox_inches="tight")

# %%
# Paired t-tests
with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4cresults1_ts_exp_matrix_middle_-1-1.5.json") as f:
    ts_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4cresults2_psd_exp_matrix_middle_-1-1.5.json") as f:
    psd_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp4cresults3_specmod_exp_matrix_middle_-1-1.5.json") as f:
    spec_data = json.load(f)

ts = np.array(ts_data["all_distributions"][0])
psd = np.array(psd_data["all_distributions"][0])
spec = np.array(spec_data["all_distributions"][0])

t, p = ttest_rel(ts, psd)
print(f"Time series vs PSD: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(ts, spec)
print(f"Time series vs Spectral model: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd, spec)
print(f"PSD vs Spectral model: t = {t:.3f}, p = {p:.5f}")
# Out:
# Time series vs PSD: t = 0.859, p = 0.39247
# Time series vs Spectral model: t = -6.284, p = 0.00000
# PSD vs Spectral model: t = -23.600, p = 0.00000

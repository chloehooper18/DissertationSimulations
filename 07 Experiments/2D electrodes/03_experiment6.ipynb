# %% [markdown]
# #### Experiment 6a
# - 2D
# - Linear variation - electrode exponents vary from -1 to -2
# - Compute PSD in both log and linear space
# - 25 electrodes
# - Aperiodic noise only
# - Average by PSD and SpecMod. Do not produce plots, save outputs
# - Load in JSON output summaries and plot a single combined plot

# %%
# Imports for functionality 
from dissertation_simulations.time_series import sweep_electrodes_ts_2D
from dissertation_simulations.psd import sweep_electrodes_psd_2D
from dissertation_simulations.spec_mod import sweep_electrodes_specmod_2D
from dissertation_simulations.exponents import generate_spatial_exponent_matrix, generate_2D_exponent_matrix
from dissertation_simulations.plotting import plot_summary_boxplots

import numpy as np
import json

from scipy.stats import ttest_rel

# %%
# Define exponent matrix
exp_matrix = generate_2D_exponent_matrix(grid_shape=(5, 5), exp_range=(-2, -1), gradient_axis="cols")
exp_matrix
# Out:
# array([[-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ]])

# %%
# Average the PSD - linear space
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, psd_average_space="linear",
                                                              n_repeats=100, plot=False, return_full=True)

exp6a_result1_psd_linear = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6aresults1_psd_linear_exp_matrix_cols_-1-2.json", "w") as f:
    json.dump(exp6a_result1_psd_linear, f, indent=4)

# Average the PSD - log space
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, psd_average_space="log",
                                                              n_repeats=100, plot=False, return_full=True)

exp6a_result2_psd_log = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6aresults2_psd_log_exp_matrix_cols_-1-2.json", "w") as f:
    json.dump(exp6a_result2_psd_log, f, indent=4)

# Average the SpecMod
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_specmod_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp6a_result3_specmod = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6aresults3_specmod_exp_matrix_cols_-1-2.json", "w") as f:
    json.dump(exp6a_result3_specmod, f, indent=4)


# Loading summaries and combining into a single plot
summary_paths = [
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6aresults1_psd_linear_exp_matrix_cols_-1-2.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6aresults2_psd_log_exp_matrix_cols_-1-2.json", 
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6aresults3_specmod_exp_matrix_cols_-1-2.json"
]

labels = [
    "Average PSD - linear",
    "Average PSD - log", 
    "Average spectral model"
]

fig, ax = plot_summary_boxplots(
    summary_paths=summary_paths,
    labels=labels,
    true_mean_exp=np.mean(-exp_matrix)
)

fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\Combined plots\exp6a_combined_plot_2D_exp_matrix_cols_-1-2.png", dpi=300, bbox_inches="tight")
# Out:
# {'exponent': array([[-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ]]), 'psd_average_space': 'linear'}
# {'exponent': array([[-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ],
#        [-2.  , -1.75, -1.5 , -1.25, -1.  ]]), 'psd_average_space': 'log'}

# %%
# Paired t-tests
with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6aresults1_psd_linear_exp_matrix_cols_-1-2.json") as f:
    psd_linear_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6aresults2_psd_log_exp_matrix_cols_-1-2.json") as f:
    psd_log_data = json.load(f)

with open (r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6aresults3_specmod_exp_matrix_cols_-1-2.json") as f:
    spec_data = json.load(f)

psd_linear = np.array(psd_linear_data["all_distributions"][0])
psd_log = np.array(psd_log_data["all_distributions"][0])
spec = np.array(spec_data["all_distributions"][0])

t, p = ttest_rel(psd_linear, psd_log)
print(f"PSD - linear averaging vs PSD - log averaging: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd_linear, spec)
print(f"PSD - linear averaging vs Spectral model: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd_log, spec)
print(f"PSD - log averaging vs Spectral model: t = {t:.3f}, p = {p:.5f}")
# Out:
# PSD - linear averaging vs PSD - log averaging: t = -41.588, p = 0.00000
# PSD - linear averaging vs Spectral model: t = -47.555, p = 0.00000
# PSD - log averaging vs Spectral model: t = -6.527, p = 0.00000

# %% [markdown]
# #### Experiment 6b
# - 2D
# - Linear variation - electrode exponents vary from -1 to -1.5 - "middle out"
# - Compute PSD in both log and linear space
# - 25 electrodes
# - Aperiodic noise only
# - Average by PSD and SpecMod. Do not produce plots, save outputs
# - Load in JSON output summaries and plot a single combined plot

# %%
# Define exponent matrix
exp_matrix = generate_spatial_exponent_matrix(grid_shape=(5, 5), exp_min=-1.5, exp_max=-1, pattern="middle")
exp_matrix
# Out:
# array([[-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ]])

# %%
# Average the PSD - linear space
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, psd_average_space="linear",
                                                              n_repeats=100, plot=False, return_full=True)

exp6b_result1_psd_linear = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6bresults1_psd_linear_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp6b_result1_psd_linear, f, indent=4)

# Average the PSD - log space
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, psd_average_space="log",
                                                              n_repeats=100, plot=False, return_full=True)

exp6b_result2_psd_log = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6bresults2_psd_log_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp6b_result2_psd_log, f, indent=4)

# Average the SpecMod
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_specmod_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp6b_result3_specmod = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6bresults3_specmod_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp6b_result3_specmod, f, indent=4)


# Loading summaries and combining into a single plot
summary_paths = [
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6bresults1_psd_linear_exp_matrix_middle_-1-1.5.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6bresults2_psd_log_exp_matrix_middle_-1-1.5.json", 
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6bresults3_specmod_exp_matrix_middle_-1-1.5.json"
]

labels = [
    "Average PSD - linear",
    "Average PSD - log", 
    "Average spectral model"
]

fig, ax = plot_summary_boxplots(
    summary_paths=summary_paths,
    labels=labels,
    true_mean_exp=np.mean(-exp_matrix)
)

fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\Combined plots\exp6b_combined_plot_2D_exp_matrix_middle_-1-1.5.png", dpi=300, bbox_inches="tight")
# Out:
# {'exponent': array([[-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ]]), 'psd_average_space': 'linear'}
# {'exponent': array([[-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ],
#        [-1.  , -1.25, -1.5 , -1.25, -1.  ]]), 'psd_average_space': 'log'}

# %%
# Paired t-tests
with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6bresults1_psd_linear_exp_matrix_middle_-1-1.5.json") as f:
    psd_linear_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6bresults2_psd_log_exp_matrix_middle_-1-1.5.json") as f:
    psd_log_data = json.load(f)

with open (r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6bresults3_specmod_exp_matrix_middle_-1-1.5.json") as f:
    spec_data = json.load(f)

psd_linear = np.array(psd_linear_data["all_distributions"][0])
psd_log = np.array(psd_log_data["all_distributions"][0])
spec = np.array(spec_data["all_distributions"][0])

t, p = ttest_rel(psd_linear, psd_log)
print(f"PSD - linear averaging vs PSD - log averaging: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd_linear, spec)
print(f"PSD - linear averaging vs Spectral model: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd_log, spec)
print(f"PSD - log averaging vs Spectral model: t = {t:.3f}, p = {p:.5f}")
# Out:
# PSD - linear averaging vs PSD - log averaging: t = -15.847, p = 0.00000
# PSD - linear averaging vs Spectral model: t = -21.424, p = 0.00000
# PSD - log averaging vs Spectral model: t = -6.020, p = 0.00000

# %% [markdown]
# #### Experiment 6c
# - 2D
# - Linear variation - electrode exponents vary from -1 to -1.5 - "middle in"
# - Compute PSD in both log and linear space
# - 25 electrodes
# - Aperiodic noise only
# - Average by PSD and SpecMod. Do not produce plots, save outputs
# - Load in JSON output summaries and plot a single combined plot

# %%
# Define exponent matrix
exp_matrix = generate_spatial_exponent_matrix(grid_shape=(5, 5), exp_min=-1, exp_max=-1.5, pattern="middle")
exp_matrix
# Out:
# array([[-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ]])

# %%
# Average the PSD - linear space
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, psd_average_space="linear",
                                                              n_repeats=100, plot=False, return_full=True)

exp6c_result1_psd_linear = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6cresults1_psd_linear_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp6c_result1_psd_linear, f, indent=4)

# Average the PSD - log space
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, psd_average_space="log",
                                                              n_repeats=100, plot=False, return_full=True)

exp6c_result2_psd_log = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6cresults2_psd_log_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp6c_result2_psd_log, f, indent=4)

# Average the SpecMod
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_specmod_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp6c_result3_specmod = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6cresults3_specmod_exp_matrix_middle_-1-1.5.json", "w") as f:
    json.dump(exp6c_result3_specmod, f, indent=4)


# Loading summaries and combining into a single plot
summary_paths = [
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6cresults1_psd_linear_exp_matrix_middle_-1-1.5.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6cresults2_psd_log_exp_matrix_middle_-1-1.5.json", 
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6cresults3_specmod_exp_matrix_middle_-1-1.5.json"
]

labels = [
    "Average PSD - linear",
    "Average PSD - log", 
    "Average spectral model"
]

fig, ax = plot_summary_boxplots(
    summary_paths=summary_paths,
    labels=labels,
    true_mean_exp=np.mean(-exp_matrix)
)

fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\Combined plots\exp6c_combined_plot_2D_exp_matrix_middle_-1-1.5.png", dpi=300, bbox_inches="tight")
# Out:
# {'exponent': array([[-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ]]), 'psd_average_space': 'linear'}
# {'exponent': array([[-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ],
#        [-1.5 , -1.25, -1.  , -1.25, -1.5 ]]), 'psd_average_space': 'log'}

# %%
# Paired t-tests
with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6cresults1_psd_linear_exp_matrix_middle_-1-1.5.json") as f:
    psd_linear_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6cresults2_psd_log_exp_matrix_middle_-1-1.5.json") as f:
    psd_log_data = json.load(f)

with open (r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6cresults3_specmod_exp_matrix_middle_-1-1.5.json") as f:
    spec_data = json.load(f)

psd_linear = np.array(psd_linear_data["all_distributions"][0])
psd_log = np.array(psd_log_data["all_distributions"][0])
spec = np.array(spec_data["all_distributions"][0])

t, p = ttest_rel(psd_linear, psd_log)
print(f"PSD - linear averaging vs PSD - log averaging: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd_linear, spec)
print(f"PSD - linear averaging vs Spectral model: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd_log, spec)
print(f"PSD - log averaging vs Spectral model: t = {t:.3f}, p = {p:.5f}")
# Out:
# PSD - linear averaging vs PSD - log averaging: t = -17.168, p = 0.00000
# PSD - linear averaging vs Spectral model: t = -23.616, p = 0.00000
# PSD - log averaging vs Spectral model: t = -6.679, p = 0.00000

# %% [markdown]
# #### Experiment 6d
# - 2D
# - Linear variation - electrode exponents vary from -1 to -2 - radial
# - Compute PSD in both log and linear space
# - 25 electrodes
# - Aperiodic noise only
# - Average by PSD and SpecMod. Do not produce plots, save outputs
# - Load in JSON output summaries and plot a single combined plot

# %%
# Define exponent matrix
exp_matrix = generate_spatial_exponent_matrix(grid_shape=(5, 5), exp_min=-2, exp_max=-1, pattern="radial")
exp_matrix
# Out:
# array([[-1.        , -1.20943058, -1.29289322, -1.20943058, -1.        ],
#        [-1.20943058, -1.5       , -1.64644661, -1.5       , -1.20943058],
#        [-1.29289322, -1.64644661, -2.        , -1.64644661, -1.29289322],
#        [-1.20943058, -1.5       , -1.64644661, -1.5       , -1.20943058],
#        [-1.        , -1.20943058, -1.29289322, -1.20943058, -1.        ]])

# %%
# Average the PSD - linear space
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, psd_average_space="linear",
                                                              n_repeats=100, plot=False, return_full=True)

exp6d_result1_psd_linear = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6dresults1_psd_linear_exp_matrix_radial_-1-2.json", "w") as f:
    json.dump(exp6d_result1_psd_linear, f, indent=4)

# Average the PSD - log space
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_psd_2D(grid_range=[(5, 5)], exponent=exp_matrix, psd_average_space="log",
                                                              n_repeats=100, plot=False, return_full=True)

exp6d_result2_psd_log = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6dresults2_psd_log_exp_matrix_radial_-1-2.json", "w") as f:
    json.dump(exp6d_result2_psd_log, f, indent=4)

# Average the SpecMod
electrodes, means, stds, errors, all_distributions, fig = sweep_electrodes_specmod_2D(grid_range=[(5, 5)], exponent=exp_matrix, 
                                                              n_repeats=100, plot=False, return_full=True)

exp6d_result3_specmod = {
    "electrodes": electrodes.tolist(),
    "all_distributions": [d.tolist() for d in all_distributions]
}

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6dresults3_specmod_exp_matrix_radial_-1-2.json", "w") as f:
    json.dump(exp6d_result3_specmod, f, indent=4)


# Loading summaries and combining into a single plot
summary_paths = [
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6dresults1_psd_linear_exp_matrix_radial_-1-2.json",
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6dresults2_psd_log_exp_matrix_radial_-1-2.json", 
    r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6dresults3_specmod_exp_matrix_radial_-1-2.json"
]

labels = [
    "Average PSD - linear",
    "Average PSD - log", 
    "Average spectral model"
]

fig, ax = plot_summary_boxplots(
    summary_paths=summary_paths,
    labels=labels,
    true_mean_exp=np.mean(-exp_matrix)
)

fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\Combined plots\exp6d_combined_plot_2D_exp_matrix_radial_-1-2.png", dpi=300, bbox_inches="tight")
# Out:
# {'exponent': array([[-1.        , -1.20943058, -1.29289322, -1.20943058, -1.        ],
#        [-1.20943058, -1.5       , -1.64644661, -1.5       , -1.20943058],
#        [-1.29289322, -1.64644661, -2.        , -1.64644661, -1.29289322],
#        [-1.20943058, -1.5       , -1.64644661, -1.5       , -1.20943058],
#        [-1.        , -1.20943058, -1.29289322, -1.20943058, -1.        ]]), 'psd_average_space': 'linear'}
# {'exponent': array([[-1.        , -1.20943058, -1.29289322, -1.20943058, -1.        ],
#        [-1.20943058, -1.5       , -1.64644661, -1.5       , -1.20943058],
#        [-1.29289322, -1.64644661, -2.        , -1.64644661, -1.29289322],
#        [-1.20943058, -1.5       , -1.64644661, -1.5       , -1.20943058],
#        [-1.        , -1.20943058, -1.29289322, -1.20943058, -1.        ]]), 'psd_average_space': 'log'}

# %%
#### Paired t-tests
with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6dresults1_psd_linear_exp_matrix_radial_-1-2.json") as f:
    psd_linear_data = json.load(f)

with open(r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6dresults2_psd_log_exp_matrix_radial_-1-2.json") as f:
    psd_log_data = json.load(f)

with open (r"C:\Users\chloe\DissertationSimulations\Result summaries\2D electrodes\exp6dresults3_specmod_exp_matrix_radial_-1-2.json") as f:
    spec_data = json.load(f)

psd_linear = np.array(psd_linear_data["all_distributions"][0])
psd_log = np.array(psd_log_data["all_distributions"][0])
spec = np.array(spec_data["all_distributions"][0])

t, p = ttest_rel(psd_linear, psd_log)
print(f"PSD - linear averaging vs PSD - log averaging: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd_linear, spec)
print(f"PSD - linear averaging vs Spectral model: t = {t:.3f}, p = {p:.5f}")

t, p = ttest_rel(psd_log, spec)
print(f"PSD - log averaging vs Spectral model: t = {t:.3f}, p = {p:.5f}")
# Out:
# PSD - linear averaging vs PSD - log averaging: t = -26.370, p = 0.00000
# PSD - linear averaging vs Spectral model: t = -30.335, p = 0.00000
# PSD - log averaging vs Spectral model: t = -3.997, p = 0.00012

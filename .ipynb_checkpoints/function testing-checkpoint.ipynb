# %%
from neurodsp.plts import plot_time_series
from dissertation_simulations.params import setup_Cz_simulation_ap
from dissertation_simulations.cz_signal_simulations import generate_cz_signal_ap

# %%
params, times = setup_Cz_simulation_ap()
cz_signal_ap = generate_cz_signal_ap()

# %%
plot_time_series(cz_signal_ap, times)

# %%
print(cz_signal_ap.shape)
print(times.shape)
# Out:
# (25000,)
# (25000,)

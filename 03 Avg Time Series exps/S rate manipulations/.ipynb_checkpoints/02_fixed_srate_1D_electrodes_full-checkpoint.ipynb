# %% [markdown]
# ### Averaging Time Series for multiple ppts
# - Function that calculates average time series for n repeats, calculates PSD and fits Spectral Model
# - Function uses base params but these can be overridden to allow for different manipulations
# - This notebook contains full signals

# %% [markdown]
# #### Experiment 1
# - Simulate 3 electrodes where the sampling rate is 250 for each, all other params use the pre-set base params, full signal
# - Average these time series together, plot the PSD and the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
# Imports required for functionality 
from dissertation_simulations.time_series import avg_time_series_distribution
from dissertation_simulations.params import electrode_sim_params_full

# %%
avg_time_series_distribution(n_repeats=100, n_electrodes=3, base_params=electrode_sim_params_full, s_rate=250)
# Out:
# (array([1.50188425, 1.48408548, 1.46209546, 1.55834746, 1.57726948,
#         1.49531213, 1.54337227, 1.47329583, 1.52906302, 1.51405783,
#         1.46128081, 1.58167792, 1.60621282, 1.48731286, 1.45626123,
#         1.5229324 , 1.61718667, 1.56175528, 1.54155563, 1.49355428,
#         1.50707342, 1.54869966, 1.50369012, 1.52999241, 1.58727355,
#         1.40505747, 1.59734208, 1.49541181, 1.45559386, 1.46239302,
#         1.63077829, 1.51075211, 1.55409757, 1.55414662, 1.52911762,
#         1.60206534, 1.58183966, 1.51759918, 1.53015817, 1.35921557,
#         1.52470631, 1.48207409, 1.59750786, 1.53035214, 1.49768909,
#         1.60066412, 1.56993517, 1.40886151, 1.44687134, 1.45157476,
#         1.50585241, 1.45705836, 1.56912327, 1.5715339 , 1.48081702,
#         1.54831289, 1.54801512, 1.4548774 , 1.5249098 , 1.61495703,
#         1.45268447, 1.46836827, 1.52217483, 1.46189124, 1.59222228,
#         1.45800883, 1.50153333, 1.55532011, 1.48278474, 1.57004557,
#         1.38357465, 1.49046107, 1.53451485, 1.63285314, 1.56712875,
#         1.52072702, 1.58655354, 1.4484625 , 1.46446876, 1.53731596,
#         1.54598354, 1.48521981, 1.47617855, 1.4561412 , 1.54873496,
#         1.51052385, 1.45596636, 1.47563872, 1.48367598, 1.44955724,
#         1.57505271, 1.45115909, 1.60981359, 1.55029374, 1.36494819,
#         1.73713387, 1.4522736 , 1.5363773 , 1.53289174, 1.45547804]),
#  1.517006402540946,
#  0.06204477591972298)

# %% [markdown]
# #### Experiment 2
# - Simulate 3 electrodes where the sampling rate is 500 for each, all other params use the pre-set base params, full signal
# - Average these time series together, plot the PSD and the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
avg_time_series_distribution(n_repeats=100, n_electrodes=3, base_params=electrode_sim_params_full, s_rate=500)
# Out:
# (array([1.51488433, 1.48310314, 1.50273666, 1.58353535, 1.40161896,
#         1.60573068, 1.5534991 , 1.43566129, 1.56647356, 1.54632295,
#         1.55239856, 1.45987148, 1.55611643, 1.5138339 , 1.54194233,
#         1.5404654 , 1.48074468, 1.53084376, 1.54167183, 1.47175496,
#         1.50628182, 1.49551848, 1.60214631, 1.55012156, 1.57460853,
#         1.62255987, 1.50940962, 1.46342718, 1.4976016 , 1.43705524,
#         1.50142491, 1.55235307, 1.58452739, 1.55653201, 1.45607588,
#         1.45825853, 1.46662802, 1.48263058, 1.5648298 , 1.53099562,
#         1.55850012, 1.556956  , 1.62516146, 1.57794464, 1.50727755,
#         1.40615312, 1.54959361, 1.52133204, 1.46998579, 1.63396271,
#         1.55450922, 1.49701048, 1.48667534, 1.53465436, 1.50338907,
#         1.49785228, 1.54774295, 1.59958794, 1.46930326, 1.49707184,
#         1.53173667, 1.39855262, 1.48494925, 1.55727874, 1.59094524,
#         1.50009736, 1.50970806, 1.49486874, 1.57270699, 1.57470331,
#         1.44215165, 1.53534833, 1.46145148, 1.58435604, 1.53755887,
#         1.60474083, 1.53052349, 1.51062231, 1.54121444, 1.52520589,
#         1.53992124, 1.37994729, 1.54485606, 1.50077017, 1.48842472,
#         1.57412155, 1.43613092, 1.54715704, 1.56650932, 1.50995225,
#         1.54750484, 1.56564353, 1.43124818, 1.6470343 , 1.5183334 ,
#         1.60367359, 1.55827534, 1.42603795, 1.49546035, 1.44692921]),
#  1.522075107535189,
#  0.05479069743136415)

# %% [markdown]
# #### Experiment 3
# - Simulate 3 electrodes where the sampling rate is 750 for each, all other params use the pre-set base params, full signal
# - Average these time series together, plot the PSD and the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
avg_time_series_distribution(n_repeats=100, n_electrodes=3, base_params=electrode_sim_params_full, s_rate=750)
# Out:
# (array([1.52080737, 1.48245775, 1.59124559, 1.50577436, 1.53651215,
#         1.55718462, 1.5903355 , 1.57017892, 1.50124829, 1.46546676,
#         1.5297545 , 1.55588057, 1.43747289, 1.4736497 , 1.55814855,
#         1.57890083, 1.30909298, 1.5522299 , 1.58235213, 1.57055238,
#         1.57497735, 1.38423792, 1.48723232, 1.54371754, 1.43297235,
#         1.49090778, 1.41741006, 1.56294091, 1.49268341, 1.67791742,
#         1.44982257, 1.55702974, 1.42259259, 1.67592365, 1.64803988,
#         1.48245197, 1.54944649, 1.60588382, 1.51989975, 1.53051088,
#         1.61295189, 1.43211487, 1.42387406, 1.53454004, 1.55757472,
#         1.4793612 , 1.50730487, 1.65218952, 1.51095289, 1.45960596,
#         1.61306697, 1.52526271, 1.5157383 , 1.46415799, 1.52747568,
#         1.54793947, 1.50764476, 1.43760594, 1.66060745, 1.57066521,
#         1.53909531, 1.3934372 , 1.4556253 , 1.56090507, 1.47963089,
#         1.50229087, 1.51459362, 1.43041308, 1.45466536, 1.47082758,
#         1.41592489, 1.43680074, 1.62679234, 1.53157116, 1.65645742,
#         1.5069296 , 1.57173316, 1.45701465, 1.50697621, 1.45947594,
#         1.57198915, 1.63038604, 1.49731195, 1.56082438, 1.53053164,
#         1.56696674, 1.53090335, 1.55449459, 1.52929002, 1.59730738,
#         1.48311864, 1.47122259, 1.46849428, 1.55208396, 1.50806103,
#         1.58645323, 1.40511075, 1.42467273, 1.45957724, 1.53690167]),
#  1.5195334040660708,
#  0.06904710506665468)

# %% [markdown]
# #### Experiment 4
# - Simulate 3 electrodes where the sampling rate is 1000 for each, all other params use the pre-set base params, full signal
# - Average these time series together, plot the PSD and the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
avg_time_series_distribution(n_repeats=100, n_electrodes=3, base_params=electrode_sim_params_full, s_rate=1000)
# Out:
# (array([1.46051231, 1.44069914, 1.6716118 , 1.46331862, 1.47790734,
#         1.4188308 , 1.54366695, 1.59371946, 1.48480014, 1.52987431,
#         1.59373963, 1.57664066, 1.5964446 , 1.58129048, 1.38277472,
#         1.54418099, 1.57776802, 1.47766092, 1.47275578, 1.52882254,
#         1.42388458, 1.47360054, 1.57683594, 1.4784842 , 1.56893552,
#         1.44634755, 1.52638608, 1.44457356, 1.51644645, 1.58160349,
#         1.4308782 , 1.55059998, 1.47239206, 1.44530435, 1.39046415,
#         1.51642057, 1.51303682, 1.58903116, 1.53790084, 1.62493672,
#         1.59190515, 1.51953115, 1.46407963, 1.45854918, 1.50657972,
#         1.51545677, 1.4591208 , 1.5610443 , 1.49547109, 1.49819406,
#         1.55172481, 1.45607147, 1.42834324, 1.51342104, 1.45587653,
#         1.54676518, 1.56104869, 1.431507  , 1.50335493, 1.53983359,
#         1.63733334, 1.53545737, 1.51387033, 1.45221428, 1.55105951,
#         1.40990646, 1.54745974, 1.50490882, 1.59568855, 1.42726582,
#         1.4966419 , 1.66719678, 1.50246994, 1.59435163, 1.58241096,
#         1.46986404, 1.52704366, 1.58385656, 1.43345218, 1.49546377,
#         1.58629221, 1.44981392, 1.50875037, 1.52222677, 1.41611526,
#         1.59337141, 1.45172558, 1.55485504, 1.50603902, 1.45195036,
#         1.58810658, 1.46437852, 1.51774074, 1.48860641, 1.50463212,
#         1.54805556, 1.58827589, 1.52385526, 1.55605222, 1.5705711 ]),
#  1.5150229024085158,
#  0.06139776057426938)

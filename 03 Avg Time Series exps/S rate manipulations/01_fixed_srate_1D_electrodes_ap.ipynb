# %% [markdown]
# ### Averaging Time Series for multiple ppts
# - Function that calculates average time series for n repeats, calculates PSD and fits Spectral Model
# - Function uses base params but these can be overridden to allow for different manipulations
# - This notebook contains aperiodic signals only

# %% [markdown]
# #### Experiment 1
# - Simulate 3 electrodes where the sampling rate is 250 for each, all other params use the pre-set base params, aperiodic noise only
# - Average these time series together, plot the PSD and the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
# Imports required for functionality 
from dissertation_simulations.time_series import avg_time_series_distribution

# %%
avg_time_series_distribution(n_repeats=100, n_electrodes=3, s_rate=250)
# Out:
# (array([1.49908517, 1.53090488, 1.51757069, 1.52141376, 1.49124022,
#         1.36605804, 1.57185333, 1.52935514, 1.4785547 , 1.44582813,
#         1.56887675, 1.50071837, 1.44999832, 1.40274962, 1.50530473,
#         1.50433128, 1.50503656, 1.56267205, 1.48387744, 1.50782281,
#         1.50177351, 1.51450997, 1.57408257, 1.49539752, 1.60445364,
#         1.53508333, 1.5295242 , 1.49042905, 1.51905555, 1.52204025,
#         1.55018925, 1.574257  , 1.45047411, 1.48609862, 1.64598762,
#         1.54672082, 1.47143775, 1.42544607, 1.52121312, 1.52270617,
#         1.53588858, 1.62154917, 1.4935088 , 1.58494937, 1.60849493,
#         1.58054443, 1.51118091, 1.49961805, 1.52746524, 1.59554307,
#         1.40031314, 1.42294734, 1.48448126, 1.48010139, 1.35551085,
#         1.5384537 , 1.45895824, 1.4705102 , 1.46369121, 1.36354991,
#         1.51706843, 1.58640533, 1.55249696, 1.532976  , 1.5058996 ,
#         1.57238289, 1.46211635, 1.53809161, 1.54073944, 1.51826778,
# ...

# %% [markdown]
# #### Experiment 2
# - Simulate 3 electrodes where the sampling rate is 500 for each, all other params use the pre-set base params, aperiodic noise only
# - Average these time series together, plot the PSD and the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
avg_time_series_distribution(n_repeats=100, n_electrodes=3, s_rate=500)
# Out:
# (array([1.52760397, 1.59036001, 1.46602817, 1.60424781, 1.53457224,
#         1.53224529, 1.5697154 , 1.49018882, 1.54190167, 1.59699322,
#         1.58130331, 1.53105819, 1.48974963, 1.44638182, 1.56582835,
#         1.46769845, 1.54859542, 1.5415334 , 1.48181899, 1.56080951,
#         1.50116681, 1.54302994, 1.42341529, 1.51817207, 1.50573234,
#         1.50663315, 1.55182849, 1.46591177, 1.63772604, 1.57744801,
#         1.56909997, 1.54723646, 1.52199902, 1.50566246, 1.50166998,
#         1.59306182, 1.53560293, 1.39587761, 1.55169776, 1.49425812,
#         1.55580395, 1.49664352, 1.4771599 , 1.5157793 , 1.5402159 ,
#         1.58108392, 1.48871255, 1.5682183 , 1.46691178, 1.53237775,
#         1.54578459, 1.58736689, 1.51369402, 1.51412929, 1.44974613,
#         1.55219617, 1.53729994, 1.5006302 , 1.41326015, 1.5305579 ,
#         1.53936676, 1.61064624, 1.47851112, 1.59345326, 1.44028101,
#         1.37082073, 1.54835732, 1.64706044, 1.50080066, 1.59295956,
# ...

# %% [markdown]
# #### Experiment 3
# - Simulate 3 electrodes where the sampling rate is 750 for each, all other params use the pre-set base params, aperiodic noise only
# - Average these time series together, plot the PSD and the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
avg_time_series_distribution(n_repeats=100, n_electrodes=3, s_rate=750)
# Out:
# (array([1.5650838 , 1.51025382, 1.60294802, 1.61588189, 1.53309186,
#         1.53850349, 1.49146313, 1.54961767, 1.54437804, 1.56539096,
#         1.52650168, 1.54595325, 1.54377594, 1.39534299, 1.47827526,
#         1.47359549, 1.48036556, 1.55170592, 1.58502476, 1.52115628,
#         1.51810259, 1.50512425, 1.53629186, 1.48234763, 1.58949726,
#         1.56301142, 1.40267204, 1.507092  , 1.57767807, 1.57246378,
#         1.47971284, 1.57854346, 1.48220328, 1.57548824, 1.45027373,
#         1.52638591, 1.49629976, 1.57483025, 1.56200454, 1.47565258,
#         1.54549494, 1.52766065, 1.52515731, 1.40925466, 1.61336345,
#         1.50826156, 1.47687622, 1.50377643, 1.31074332, 1.39941315,
#         1.55949078, 1.53379122, 1.47367376, 1.31817713, 1.45659181,
#         1.43673118, 1.46581858, 1.56417262, 1.58492732, 1.54728764,
#         1.59872273, 1.63503746, 1.53744476, 1.52634162, 1.47055597,
#         1.5416466 , 1.46057039, 1.52296845, 1.46958234, 1.50300721,
# ...

# %% [markdown]
# #### Experiment 4
# - Simulate 3 electrodes where the sampling rate is 1000 for each, all other params use the pre-set base params, aperiodic noise only
# - Average these time series together, plot the PSD and the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
avg_time_series_distribution(n_repeats=100, n_electrodes=3, s_rate=1000)
# Out:
# (array([1.45763867, 1.56986484, 1.53889838, 1.52152617, 1.50272319,
#         1.47138981, 1.52645126, 1.64879872, 1.560509  , 1.56489378,
#         1.51112347, 1.53216364, 1.57814979, 1.55353427, 1.51584828,
#         1.51539547, 1.56651096, 1.51203034, 1.48890449, 1.49650174,
#         1.51669155, 1.53822323, 1.52407775, 1.51335568, 1.51331349,
#         1.51134036, 1.45973019, 1.55436699, 1.47389266, 1.41426048,
#         1.4491769 , 1.3650297 , 1.50321185, 1.58301286, 1.53021264,
#         1.69116081, 1.55611084, 1.54907708, 1.4711878 , 1.5889816 ,
#         1.41708365, 1.49922411, 1.59284818, 1.56901595, 1.47032447,
#         1.51544186, 1.41801728, 1.52799151, 1.54752189, 1.41651122,
#         1.36540221, 1.46049555, 1.49642081, 1.41287917, 1.50360787,
#         1.4537347 , 1.55274599, 1.46454245, 1.57973524, 1.59312098,
#         1.46860156, 1.58256722, 1.43926364, 1.54069933, 1.52106328,
#         1.53986801, 1.53156114, 1.45743454, 1.49501113, 1.55517676,
# ...

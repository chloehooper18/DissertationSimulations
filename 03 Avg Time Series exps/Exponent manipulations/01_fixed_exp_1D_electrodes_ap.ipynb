# %% [markdown]
# ### Averaging Time Series for multiple ppts
# - Function that calculates average time series for n repeats, calculates PSD and fits Spectral Model
# - Function uses base params but these can be overridden to allow for different manipulations

# %% [markdown]
# #### Experiment 1
# - Simulate 3 electrodes where the exponent is -1 for each, all other params use the pre-set base params, aperiodic noise only
# - Average these time series together, plot the PSD and the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
# Imports required for functionality 
from dissertation_simulations.time_series import avg_time_series_distribution

# %%
avg_time_series_distribution(n_repeats=100, n_electrodes=3, exponent=-1)
# Out:
# (array([0.99853708, 0.93888127, 0.91262887, 1.06193427, 0.96269389,
#         0.91793048, 1.01572844, 1.18448496, 1.04382387, 1.01512458,
#         1.02048155, 0.86356909, 1.05189327, 1.20964216, 1.07240954,
#         0.90518191, 1.05137082, 1.07474581, 0.95418789, 1.05285566,
#         1.03950601, 0.97871912, 1.06506536, 0.94709514, 1.0057581 ,
#         1.04549691, 1.07488436, 1.07283401, 0.95931046, 1.0313578 ,
#         0.96526937, 0.91077603, 0.97870162, 0.85834968, 1.01353746,
#         1.00341005, 1.04812715, 1.03823083, 1.00478017, 0.99126684,
#         1.12838441, 1.01162392, 0.96153263, 0.97066674, 1.00516977,
#         1.02946417, 1.03968063, 1.07133315, 0.98338962, 1.02068461,
#         1.11967976, 1.13068979, 0.98539399, 1.04128892, 1.03796919,
#         0.85187802, 1.01246598, 1.08934526, 0.92868342, 1.08448773,
#         1.05966172, 1.05776837, 0.88869767, 1.00622127, 0.98476937,
#         1.02110989, 1.01058849, 1.06337045, 1.00852778, 0.99648669,
#         1.07049818, 0.9385712 , 1.03484107, 0.93291232, 1.03350485,
#         1.0950565 , 1.00238896, 0.93077818, 1.06733549, 0.98982828,
#         0.89103833, 0.91485742, 1.05998741, 1.02162718, 0.98204306,
#         1.00282315, 1.00320892, 1.0102198 , 0.8621551 , 1.01032815,
#         0.84047242, 0.97542955, 0.96997273, 1.09024693, 1.00920441,
#         0.9755308 , 0.91110366, 1.14266365, 0.99323758, 1.01654445]),
#  1.0072000507550347,
#  0.06897215929730666)

# %% [markdown]
# ### Averaging PSD for multiple ppts
# - Function that calculates average PSD for n repeats and then fits the Spectral Model
# - Function uses base params but these can be overridden to allow for different manipulations

# %% [markdown]
# #### Experiment 1
# - Simulate 3 electrodes where the exponent is -1 for each, all other params use the pre-set base params, aperiodic noise only
# - Average the PSD and fit the Spectral Model
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
# Imports required for functionality 
from dissertation_simulations.psd import avg_psd_distribution

# %%
avg_psd_distribution(n_repeats=100, n_electrodes=3, exponent=-1)
# Out:
# (array([1.01517656, 1.0081437 , 1.07983328, 1.03817488, 1.00865217,
#         0.96608564, 1.01017939, 0.9765516 , 0.99961109, 0.95950006,
#         1.01483439, 0.96731771, 0.97892465, 0.95572603, 0.93749438,
#         1.02977226, 0.96176104, 1.04609201, 1.01697944, 0.98478605,
#         1.0074035 , 1.00842701, 1.04101177, 0.98951355, 0.94406219,
#         1.024256  , 1.00394459, 1.03648391, 0.98288006, 1.05037167,
#         0.99882246, 0.99964909, 1.00707189, 1.03211541, 1.04073075,
#         0.99331552, 0.91608551, 1.00470434, 0.98367905, 1.03627613,
#         1.05038768, 0.97868308, 1.01761694, 1.07005177, 1.00343491,
#         1.02259385, 0.96815896, 0.96833273, 1.0158937 , 1.00873198,
#         1.01113239, 1.0385719 , 1.00112197, 1.06701864, 1.02863174,
#         0.97657624, 1.04405856, 1.05883178, 1.0401261 , 1.06478005,
#         1.00831648, 1.00131495, 0.98640514, 1.02479932, 0.95819519,
#         1.00758974, 0.99073267, 0.93448503, 0.99992968, 1.04111416,
# ...

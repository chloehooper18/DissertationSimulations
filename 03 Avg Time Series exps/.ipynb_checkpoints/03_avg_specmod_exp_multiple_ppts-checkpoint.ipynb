# %% [markdown]
# ### Averaging Spectral Models for multiple ppts
# - Function that calculates average Spectral Model exponent for n repeats
# - Function uses base params but these can be overridden to allow for different manipulations

# %% [markdown]
# #### Experiment 1
# - Simulate 3 electrodes where the exponent is -1 for each, all other params use the pre-set base params, aperiodic noise only
# - Calculate PSD for each
# - Average the Spectral Model exponent
# - Repeat this simulation n times
# - Plot all exponent outputs and look at the distribution - retrieve mean and SD values

# %%
from dissertation_simulations.spec_mod import avg_specmod_exponent_distribution

# %%
avg_specmod_exponent_distribution(n_repeats=100, n_electrodes=3, exponent=-1)
# Out:
# (array([1.03168208, 1.05802694, 0.91330775, 0.99033398, 0.97040548,
#         0.95426598, 1.02666239, 1.02825246, 1.01715916, 1.04590908,
#         1.06184543, 0.99505057, 1.04794476, 0.98351301, 0.97541333,
#         0.9772048 , 0.98343188, 1.05418651, 0.97804358, 1.03116077,
#         0.99220872, 0.95465221, 1.02620953, 1.02487049, 1.00937078,
#         1.0082024 , 0.97815034, 1.02636653, 0.99698257, 1.00440489,
#         1.03904642, 1.01567715, 0.98887437, 0.98754256, 0.93452404,
#         0.96826854, 1.0555327 , 0.98552858, 1.01702891, 0.99447212,
#         1.00781333, 1.03604696, 1.10390726, 0.92943508, 0.97070353,
#         0.98372331, 0.96298579, 0.94505389, 0.93296976, 0.92615521,
#         0.98977031, 1.0065311 , 1.02611113, 1.02074185, 1.00878839,
#         0.99791982, 1.06099296, 0.98224163, 0.98370496, 0.99899088,
#         1.05208597, 1.03362203, 1.0089602 , 1.04729602, 1.05461861,
#         1.030971  , 0.9718061 , 0.97130734, 1.02918889, 1.0051136 ,
#         0.9901648 , 1.0072188 , 1.02108625, 0.95176993, 1.04882994,
#         1.00625458, 1.02523678, 1.12582644, 1.01128556, 1.08180253,
#         1.0044148 , 0.95733404, 0.96479391, 1.03846194, 1.02004524,
#         1.02370295, 1.03774093, 0.98185549, 0.97273218, 1.00939656,
#         0.99736879, 0.98753817, 1.02355004, 1.01825577, 0.99755261,
#         1.02508132, 0.93434334, 0.97659086, 0.96428126, 1.0640054 ]),
#  1.0047979184432385,
#  0.03794640129267798)

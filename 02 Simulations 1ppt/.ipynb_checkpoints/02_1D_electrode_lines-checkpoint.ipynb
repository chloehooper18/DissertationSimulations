# %% [markdown]
# ### Simulating 1D lines of electrodes
#
# - Simulating electrodes where the exponent is -1 for each
# - Explore what happens to the output exponent when you average:
#     - The time series
#     - The PSDs
#     - The exponent outputs from the model fit
# - Simulate this for both aperiodic and full electrode signals

# %% [markdown]
# #### Imports

# %%
# Imports required for functionality 
import numpy as np
import matplotlib.pyplot as plt

from dissertation_simulations.params import electrode_sim_params_ap
from dissertation_simulations.params import electrode_sim_params_full
from dissertation_simulations.params import welch_params
from dissertation_simulations.params import spectral_model_params
from dissertation_simulations.params import freq_range

from neurodsp.plts import plot_time_series
from neurodsp.spectral import compute_spectrum_welch

from specparam import SpectralModel
from specparam.plts import plot_spectra

from dissertation_simulations.generate_electrodes import generate_1D_electrodes_ap
from dissertation_simulations.generate_electrodes import generate_1D_electrodes_full

# %% [markdown]
# #### Testing the function - 3 electrodes, aperiodic noise only, exponent = -1 for each
#
# Aim:
# - Generate 3 electrode signals
# - Each electrode signal should have an exponent of -1

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Averaging the Time Series together
#
# - Compute and plot the average time series for the 3 signals
# - Compute and plot the PSD
# - Fit the Spectral Model and see what the exponent is

# %%
# Convert to array (shape: n_electrodes × n_timepoints)
signal_array = np.array(list(signals.values()))

# Average across electrodes
avg_signal = np.mean(signal_array, axis=0)

# Plot average time series
plot_time_series(times, avg_signal)

# %% [markdown]
# ##### Plot the PSD

# %%
# Compute and plot the PSD, in the frequency domain
params = electrode_sim_params_ap
welch_dict = welch_params(params)

fig, ax = plt.subplots()

freqs, powers = compute_spectrum_welch(avg_signal, fs=params["s_rate"], **welch_dict)
plot_spectra(freqs, powers, log_powers=True, ax=ax)

ax.set_xlim(-1, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot Spectral Model

# %%
# Plot Spectral Model and look at the exponent output 
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, powers, freq_range)
# Out:
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -1.1189, 0.9973
#
#                          Peak Parameters ('gaussian' mode) 4 peaks found
#                                 CF:   5.99, PW:   0.10, BW:   3.76
#                                 CF:  15.44, PW:   0.16, BW:   2.12
#                                 CF:  26.64, PW:   0.15, BW:   5.44
#                                 CF:  34.81, PW:   0.14, BW:   1.69
#
#                                           Model metrics:
#                                      error (mae) is 0.0372
#                                   gof (rsquared) is 0.9795
#
# ==================================================================================================

# %% [markdown]
# Exponent is close to 1 - to be expected

# %% [markdown]
# #### Averaging the PSD together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the average PSD
# - Fit the Spectral Model and see what the exponent is

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot the PSD for each

# %%
psds = {}

welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Average the PSDs

# %%
power_array = np.array([powers for freqs, powers in psds.values()])
avg_powers = np.mean(power_array, axis=0)

freqs = list(psds.values())[0][0]

fig, ax = plt.subplots()

plot_spectra(freqs, avg_powers, log_powers=True, ax=ax)

ax.set_title("Average PSD")
ax.set_xlim(0, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot Spectral Model

# %%
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6141, 1.0049
#
#                          Peak Parameters ('gaussian' mode) 7 peaks found
#                                 CF:   3.47, PW:   0.06, BW:   0.67
#                                 CF:   5.34, PW:   0.07, BW:   1.42
#                                 CF:   7.37, PW:   0.08, BW:   0.72
#                                 CF:  16.74, PW:   0.08, BW:   2.08
#                                 CF:  22.66, PW:   0.09, BW:   2.05
#                                 CF:  26.57, PW:   0.11, BW:   0.64
#                                 CF:  30.13, PW:   0.10, BW:   5.74
#
#                                           Model metrics:
#                                      error (mae) is 0.0102
#                                   gof (rsquared) is 0.9978
#
# ==================================================================================================

# %% [markdown]
# Exponent is close to 1 - to be expected

# %% [markdown]
# #### Averaging the Spectral Models together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the PSDs for the 3 signals
# - Fit the Spectral Models for each signal and calculate the average exponent

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot the PSD for each

# %%
psds = {}

welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Plot the Spectral Models for each

# %%
spectral_models = {}

for name, (freqs, powers) in psds.items():

    # Fit model
    fm = SpectralModel(**spectral_model_params)
    freq_range = freq_range
    fm.report(freqs, powers, freq_range)

    spectral_models[name] = fm
# Out:
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6825, 0.9561
#
#                          Peak Parameters ('gaussian' mode) 3 peaks found
#                                 CF:   4.06, PW:   0.14, BW:   2.10
#                                 CF:  11.76, PW:   0.10, BW:   3.17
#                                 CF:  21.00, PW:   0.11, BW:   3.33
#
#                                           Model metrics:
#                                      error (mae) is 0.0272
#                                   gof (rsquared) is 0.9891
#
# ==================================================================================================
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6974, 0.9192
#
#                          Peak Parameters ('gaussian' mode) 6 peaks found
#                                 CF:   5.93, PW:   0.14, BW:   1.71
#                                 CF:  11.06, PW:   0.07, BW:   4.08
#                                 CF:  17.49, PW:   0.10, BW:   0.60
#                                 CF:  28.93, PW:   0.14, BW:   1.74
#                                 CF:  32.10, PW:   0.12, BW:   2.49
#                                 CF:  36.76, PW:   0.16, BW:   2.58
#
#                                           Model metrics:
#                                      error (mae) is 0.0198
#                                   gof (rsquared) is 0.9923
#
# ==================================================================================================
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6130, 1.0055
#
#                          Peak Parameters ('gaussian' mode) 4 peaks found
#                                 CF:   6.41, PW:   0.12, BW:   0.61
#                                 CF:  14.94, PW:   0.08, BW:   5.26
#                                 CF:  25.51, PW:   0.10, BW:   0.62
#                                 CF:  32.58, PW:   0.17, BW:   2.18
#
#                                           Model metrics:
#                                      error (mae) is 0.0307
#                                   gof (rsquared) is 0.9835
#
# ==================================================================================================

# %% [markdown]
# ##### Calculate average exponent value

# %%
exponents = []

for name, fm in spectral_models.items():
    exponent = fm.get_params('aperiodic', 'exponent')
    exponents.append(exponent)
    print(f"{name}: {exponent:.3f}")

avg_exponent = np.mean(exponents)

print(f"Average exponent: {avg_exponent:.3f}")
# Out:
# electrode_1: 0.956
# electrode_2: 0.919
# electrode_3: 1.006
# Average exponent: 0.960

# %% [markdown]
# #### Testing the function - 3 electrodes, aperiodic and periodic noise, exponent = -1 for each
#
# Aim:
# - Generate 3 electrode signals
# - Each electrode signal should have an exponent of -1

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_full(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Averaging the Time Series together
#
# - Compute and plot the average time series for the 3 signals
# - Compute and plot the PSD
# - Fit the Spectral Model and see what the exponent is

# %%
# Convert to array (shape: n_electrodes × n_timepoints)
signal_array = np.array(list(signals.values()))

# Average across electrodes
avg_signal = np.mean(signal_array, axis=0)

# Plot average time series
plot_time_series(times, avg_signal)

# %% [markdown]
# ##### Plot the PSD

# %%
# Compute and plot the PSD, in the frequency domain
params = electrode_sim_params_full
welch_dict = welch_params(params)

fig, ax = plt.subplots()

freqs, powers = compute_spectrum_welch(avg_signal, fs=params["s_rate"], **welch_dict)
plot_spectra(freqs, powers, log_powers=True, ax=ax)

ax.set_xlim(-1, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot the Spectral Model

# %%
# Plot Spectral Model and look at the exponent output 
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, powers, freq_range)
# Out:
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -1.3754, 0.9731
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.02, PW:   2.00, BW:   1.88
#
#                                           Model metrics:
#                                      error (mae) is 0.0711
#                                   gof (rsquared) is 0.9750
#
# ==================================================================================================

# %% [markdown]
# Exponent is close to 1 - to be expected

# %% [markdown]
# #### Averaging the PSD together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the average PSD
# - Fit the Spectral Model and see what the exponent is

# %%
exponents = [-1, -1, -1, -1]
signals, params_list, times = generate_1D_electrodes_full(4, exponents)

# %% [markdown]
# ##### Plot the time series for each electrode

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot indidivual PSDs

# %%
psds = {}

params = electrode_sim_params_full
welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Plot average PSD

# %%
power_array = np.array([powers for freqs, powers in psds.values()])
avg_powers = np.mean(power_array, axis=0)

freqs = list(psds.values())[0][0]

fig, ax = plt.subplots()

plot_spectra(freqs, avg_powers, log_powers=True, ax=ax)

ax.set_title("Average PSD")
ax.set_xlim(0, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot the Spectral Model

# %%
# Plot Spectral Model and look at the exponent output 
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.8942, 0.9902
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.03, PW:   1.47, BW:   1.78
#
#                                           Model metrics:
#                                      error (mae) is 0.0350
#                                   gof (rsquared) is 0.9910
#
# ==================================================================================================

# %% [markdown]
# Exponet close to 1 - to be expected

# %% [markdown]
# #### Averaging the Spectral Models together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the PSDs for the 3 signals
# - Fit the Spectral Models for each signal and calculate the average exponent

# %%
exponents = [-1, -1, -1, -1]
signals, params_list, times = generate_1D_electrodes_full(4, exponents)

# %% [markdown]
# ##### Plot the Time Series for each electrode

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot individual PSDs

# %%
psds = {}

params = electrode_sim_params_full
welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Plot individual Spectral Models

# %%
spectral_models = {}

for name, (freqs, powers) in psds.items():

    # Fit model
    fm = SpectralModel(**spectral_model_params)
    freq_range = freq_range
    fm.report(freqs, powers, freq_range)

    spectral_models[name] = fm
# Out:
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.9153, 0.9654
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.02, PW:   1.48, BW:   1.80
#
#                                           Model metrics:
#                                      error (mae) is 0.0521
#                                   gof (rsquared) is 0.9809
#
# ==================================================================================================
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.8427, 1.0389
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.03, PW:   1.46, BW:   1.77
#
#                                           Model metrics:
#                                      error (mae) is 0.0560
#                                   gof (rsquared) is 0.9814
#
# ==================================================================================================
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.9856, 0.9373
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.05, PW:   1.55, BW:   1.82
#
#                                           Model metrics:
#                                      error (mae) is 0.0601
#                                   gof (rsquared) is 0.9768
#
# ==================================================================================================
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.9256, 0.9767
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.03, PW:   1.47, BW:   1.92
#
#                                           Model metrics:
#                                      error (mae) is 0.0392
#                                   gof (rsquared) is 0.9883
#
# ==================================================================================================

# %% [markdown]
# ##### Average Spectral Model exponent

# %%
exponents = []

for name, fm in spectral_models.items():
    exponent = fm.get_params('aperiodic', 'exponent')
    exponents.append(exponent)
    print(f"{name}: {exponent:.3f}")

avg_exponent = np.mean(exponents)

print(f"Average exponent: {avg_exponent:.3f}")
# Out:
# electrode_1: 0.965
# electrode_2: 1.039
# electrode_3: 0.937
# electrode_4: 0.977
# Average exponent: 0.980

# %% [markdown]
# ### Simulating 2D lines of electrodes
#
# - Simulating electrode clusters where the exponent is a random value between -1 and -2
# - Average the PSD and plot the Spectral Model
# - Simulate this for aperiodic signals only

# %% [markdown]
# ##### Imports

# %%
# Imports required for functionality 
import numpy as np
import matplotlib.pyplot as plt

from dissertation_simulations.params import electrode_sim_params_ap

from dissertation_simulations.generate_electrodes import generate_2D_electrodes_ap
from dissertation_simulations.psd import avg_psd_2D
from dissertation_simulations.exponents import gen_exponents
from dissertation_simulations.params import spectral_model_params

from specparam import SpectralModel
from dissertation_simulations.params import freq_range

# %% [markdown]
# #### 2x2 electrode cluster
# - Simulate a 2x2 electrode with random exponents between -1 and -2
# - Calculate the average PSD and plot the spectral model

# %%
# Load in copy of parameters
params = electrode_sim_params_ap.copy()

# Generate random exponents
exponents = gen_exponents(4, (-2, -1))
print(exponents)

# Generate electrode cluster
grid_signals, times = generate_2D_electrodes_ap(2, 2, exponents)

# Compute and plot average PSD
psds, avg_powers, freqs = avg_psd_2D(grid_signals, params)

# Fit and plot Spectral model
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# [-1.5866219337279608, -1.0312965024220087, -1.39502708676351, -1.4295183661607902]
# ...
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.3132, 1.3475
#
#                          Peak Parameters ('gaussian' mode) 3 peaks found
#                                 CF:  24.54, PW:   0.08, BW:   0.55
#                                 CF:  29.86, PW:   0.09, BW:   5.02
#                                 CF:  38.00, PW:   0.08, BW:   1.61
#
#                                           Model metrics:
#                                      error (mae) is 0.0198
#                                   gof (rsquared) is 0.9961
#
# ...

# %% [markdown]
# #### 3x3 electrode cluster
# - Simulate a 3x3 electrode with random exponents between -1 and -2
# - Calculate the average PSD and plot the spectral model

# %%
# Load in copy of parameters
params = electrode_sim_params_ap.copy()

# Generate random exponents
exponents = gen_exponents(9, (-2, -1))
print(exponents)

# Generate electrode cluster
grid_signals, times = generate_2D_electrodes_ap(3, 3, exponents)

# Compute and plot average PSD
psds, avg_powers, freqs = avg_psd_2D(grid_signals, params)

# Fit and plot Spectral model
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# [-1.6037431834609102, -1.380539040407131, -1.0201728482759629, -1.6804040864657694, -1.8016956683589682, -1.9566753132522425, -1.3465181122972005, -1.7342929166978038, -1.200114447176602]
# ...
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.2424, 1.4614
#
#                          Peak Parameters ('gaussian' mode) 2 peaks found
#                                 CF:  31.11, PW:   0.05, BW:   1.27
#                                 CF:  36.25, PW:   0.04, BW:   6.17
#
#                                           Model metrics:
#                                      error (mae) is 0.0098
# ...

# %% [markdown]
# #### 4x4 electrode cluster
# - Simulate a 4x4 electrode with random exponents between -1 and -2
# - Calculate the average PSD and plot the spectral model

# %%
# Load in copy of parameters
params = electrode_sim_params_ap.copy()

# Generate random exponents
exponents = gen_exponents(16, (-2, -1))
print(exponents)

# Generate electrode cluster
grid_signals, times = generate_2D_electrodes_ap(4, 4, exponents)

# Compute and plot average PSD
psds, avg_powers, freqs = avg_psd_2D(grid_signals, params)

# Fit and plot Spectral model
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# [-1.2991605918502884, -1.3845953855516373, -1.8999854039866646, -1.4364720135843427, -1.4640828758826792, -1.250213685219317, -1.6392415986353592, -1.5612869321483749, -1.7482779303620561, -1.64627559451764, -1.6214390204996927, -1.6217155305191544, -1.6564376722039598, -1.9837612018910806, -1.7152220882891256, -1.3484842464441298]
# ...
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.1835, 1.5440
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  24.98, PW:   0.06, BW:   1.51
#
#                                           Model metrics:
# ...

# %% [markdown]
# #### 5x5 electrode cluster
# - Simulate a 5x5 electrode with random exponents between -1 and -2
# - Calculate the average PSD and plot the spectral model

# %%
# Load in copy of parameters
params = electrode_sim_params_ap.copy()

# Generate random exponents
exponents = gen_exponents(25, (-2, -1))
print(exponents)

# Generate electrode cluster
grid_signals, times = generate_2D_electrodes_ap(5, 5, exponents)

# Compute and plot average PSD
psds, avg_powers, freqs = avg_psd_2D(grid_signals, params)

# Fit and plot Spectral model
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# [-1.4821117346349224, -1.7993539740531157, -1.096074163923566, -1.4173578500461523, -1.2681441274937257, -1.828450174558496, -1.750172975834567, -1.07525483623437, -1.249483688873458, -1.980343205539997, -1.8818644531003865, -1.9754699826703317, -1.09531053010442, -1.414175062278535, -1.6229152191341136, -1.809355478151323, -1.3064553293217043, -1.365720946017221, -1.168574407390548, -1.9662439256086879, -1.3437556503792527, -1.6338920853319936, -1.4979126656468438, -1.144625856517838, -1.1095448610920864]
# ...
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.2724, 1.4232
#
# ...

# %% [markdown]
# #### 6x6 electrode cluster
# - Simulate a 6x6 electrode with random exponents between -1 and -2
# - Calculate the average PSD and plot the spectral model

# %%
# Load in copy of parameters
params = electrode_sim_params_ap.copy()

# Generate random exponents
exponents = gen_exponents(36, (-2, -1))
print(exponents)

# Generate electrode cluster
grid_signals, times = generate_2D_electrodes_ap(6, 6, exponents)

# Compute and plot average PSD
psds, avg_powers, freqs = avg_psd_2D(grid_signals, params)

# Fit and plot Spectral model
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# [-1
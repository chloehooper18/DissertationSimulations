# %% [markdown]
# ### Simulating 1D lines of electrodes
#
# - Simulating 3 electrodes where the exponent is -1 for each
# - Explore what happens to the output exponent when you average:
#     - The time series
#     - The PSDs
#     - The exponent outputs from the model fit
# - Simulate this for both aperiodic and full electrode signals

# %% [markdown]
# #### Imports

# %%
# Imports required for functionality 
import numpy as np
import matplotlib.pyplot as plt

from dissertation_simulations.cz_signal_simulations import generate_cz_signal_ap
from dissertation_simulations.cz_signal_simulations import generate_cz_signal_full
from dissertation_simulations.params import cz_sim_params_ap
from dissertation_simulations.params import welch_params
from dissertation_simulations.params import spectral_model_params
from dissertation_simulations.params import freq_range

from neurodsp.plts import plot_time_series
from neurodsp.spectral import compute_spectrum_welch

from specparam import SpectralModel
from specparam.plts import plot_spectra

# %% [markdown]
# #### Potential function for generating electrodes in a 1D ararry
#
# Function to generate a 1D array of n electrodes with y exponents.
# This is for an electrode signal that contains aperiodic noise only

# %%
def generate_1D_electrodes_ap(n_electrodes, exponents):
    from dissertation_simulations.params import cz_sim_params_ap, cz_times
    from neurodsp.sim import sim_powerlaw

    # Check to make sure that n_electrodes and n exponents match
    if len(exponents) != n_electrodes:
        raise ValueError("Number of exponents must match number of electrodes")

    # Base params
    base_params = cz_sim_params_ap.copy()

    n_seconds = base_params["n_seconds"]
    fs = base_params["s_rate"]
    high_pass_filter = base_params["high_pass_filter"]
    low_pass_filter = base_params["low_pass_filter"]

    times = cz_times(base_params)

    signals = {}
    params_list = []

    for i in range(n_electrodes):

        # Copy params for this electrode
        params = base_params.copy()
        params["exponent"] = exponents[i]

        # Generate signal
        signal = sim_powerlaw(
            n_seconds,
            fs,
            exponent=params["exponent"],
            f_range=[high_pass_filter, low_pass_filter]
        )

        # Store
        signals[f"electrode_{i+1}"] = signal
        params_list.append(params)

    return signals, params_list, times

# %% [markdown]
# #### Testing the function - 3 electrodes, exponent = -1 for each
#
# Aim:
# - Generate 3 electrode signals
# - Each electrode signal should have an exponent of -1

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Averaging the Time Series together
#
# - Compute and plot the average time series for the 3 signals
# - Compute and plot the PSD
# - Fit the Spectral Model and see what the exponent is

# %%
# Convert to array (shape: n_electrodes × n_timepoints)
signal_array = np.array(list(signals.values()))

# Average across electrodes
avg_signal = np.mean(signal_array, axis=0)

# Plot average time series
plot_time_series(times, avg_signal)

# %%
# Compute and plot the PSD, in the frequency domain
params = cz_sim_params_ap.copy()
welch_dict = welch_params(params)

fig, ax = plt.subplots()

freqs, powers = compute_spectrum_welch(avg_signal, fs=params["s_rate"], **welch_dict)
plot_spectra(freqs, powers, log_powers=True, ax=ax)

ax.set_xlim(-1, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot Spectral Model

# %%
# Plot Spectral Model and look at the exponent output 
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, powers, freq_range)
# Out:
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -1.1111, 0.9909
#
#                          Peak Parameters ('gaussian' mode) 7 peaks found
#                                 CF:   3.77, PW:   0.10, BW:   2.00
#                                 CF:  11.47, PW:   0.10, BW:   0.62
#                                 CF:  16.97, PW:   0.10, BW:   0.50
#                                 CF:  21.43, PW:   0.15, BW:   0.61
#                                 CF:  24.63, PW:   0.11, BW:   0.56
#                                 CF:  27.87, PW:   0.14, BW:   1.58
#                                 CF:  31.56, PW:   0.08, BW:   1.01
#
#                                           Model metrics:
#                                      error (mae) is 0.0155
#                                   gof (rsquared) is 0.9961
#
# ==================================================================================================

# %% [markdown]
# Exponent is close to 1 - to be expected

# %% [markdown]
# #### Averaging the PSD together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the average PSD
# - Fit the Spectral Model and see what the exponent is

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot the PSD for each

# %%
psds = {}

welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Average the PSDs

# %%
power_array = np.array([powers for freqs, powers in psds.values()])
avg_powers = np.mean(power_array, axis=0)

freqs = list(psds.values())[0][0]

fig, ax = plt.subplots()

plot_spectra(freqs, avg_powers, log_powers=True, ax=ax)

ax.set_title("Average PSD")
ax.set_xlim(0, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot Spectral Model

# %%
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6550, 0.9382
#
#                          Peak Parameters ('gaussian' mode) 6 peaks found
#                                 CF:   5.54, PW:   0.07, BW:   0.51
#                                 CF:   9.17, PW:   0.05, BW:   4.45
#                                 CF:  15.72, PW:   0.08, BW:   1.53
#                                 CF:  24.32, PW:   0.10, BW:   1.44
#                                 CF:  26.59, PW:   0.05, BW:   0.50
#                                 CF:  37.43, PW:   0.07, BW:   1.14
#
#                                           Model metrics:
#                                      error (mae) is 0.0123
#                                   gof (rsquared) is 0.9969
#
# ==================================================================================================

# %% [markdown]
# Exponent is close to 1 - to be expected

# %% [markdown]
# #### Averaging the Spectral Models together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the PSDs for the 3 signals
# - Fit the Spectral Models for each signal and calculate the average exponent

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot the PSD for each

# %%
psds = {}

welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Plot the Spectral Models for each

# %%
spectral_models = {}

for name, (freqs, powers) in psds.items():

    # Fit model
    fm = SpectralModel()
    freq_range = freq_range
    fm.report(freqs, powers, freq_range)

    spectral_models[name] = fm
# Out:
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.7023, 0.9368
#
#                          Peak Parameters ('gaussian' mode) 5 peaks found
#                                 CF:   5.57, PW:   0.08, BW:   3.83
#                                 CF:  16.15, PW:   0.12, BW:   2.52
#                                 CF:  21.45, PW:   0.18, BW:   1.11
#                                 CF:  24.42, PW:   0.12, BW:   3.39
#                                 CF:  32.75, PW:   0.14, BW:   1.54
#
#                                           Model metrics:
#                                      error (mae) is 0.0289
#                                   gof (rsquared) is 0.9804
#
# ==================================================================================================
#
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.5717, 1.0233
#
#                          Peak Parameters ('gaussian' mode) 4 peaks found
#                                 CF:  16.69, PW:   0.10, BW:   4.57
#                                 CF:  22.59, PW:   0.11, BW:   1.77
#                                 CF:  27.22, PW:   0.13, BW:   1.79
#                                 CF:  33.48, PW:   0.15, BW:   0.66
#
#                                           Model metrics:
#                                      error (mae) is 0.0271
#                                   gof (rsquared) is 0.9881
#
# ==================================================================================================
#
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6322, 0.9811
#
#                          Peak Parameters ('gaussian' mode) 4 peaks found
#                                 CF:   8.68, PW:   0.07, BW:   1.38
#                                 CF:  21.39, PW:   0.08, BW:   2.83
#                                 CF:  27.85, PW:   0.21, BW:   2.63
#                                 CF:  37.80, PW:   0.10, BW:   1.47
#
#                                           Model metrics:
#                                      error (mae) is 0.0176
#                                   gof (rsquared) is 0.9925
#
# ==================================================================================================

# %% [markdown]
# ##### Calculate average exponent value

# %%
exponents = []

for name, fm in spectral_models.items():
    exponent = fm.get_params('aperiodic', 'exponent')
    exponents.append(exponent)
    print(f"{name}: {exponent:.3f}")

avg_exponent = np.mean(exponents)

print(f"Average exponent: {avg_exponent:.3f}")
# Out:
# electrode_1: 0.937
# electrode_2: 1.023
# electrode_3: 0.981
# Average exponent: 0.980

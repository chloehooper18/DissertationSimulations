# %% [markdown]
# ### Simulating 2D lines of electrodes
#
# - Simulating electrodes where the exponent is -1 for each
# - Explore what happens to the output exponent when you average:
#     - The time series
#     - The PSDs
#     - The exponent outputs from the model fit
# - Simulate this for both aperiodic and full electrode signals

# %% [markdown]
# #### Imports

# %%
# Imports required for functionality 
import numpy as np
import matplotlib.pyplot as plt

from neurodsp.plts import plot_time_series
from neurodsp.spectral import compute_spectrum_welch

from specparam import SpectralModel
from specparam.plts import plot_spectra

from dissertation_simulations.params import welch_params
from dissertation_simulations.params import spectral_model_params
from dissertation_simulations.params import freq_range
from dissertation_simulations.params import cz_sim_params_ap

# %% [markdown]
# #### Potential function

# %%
def generate_2D_electrodes_ap(n_rows, n_cols, exponents):
    import numpy as np
    from dissertation_simulations.params import cz_sim_params_ap, cz_times
    from neurodsp.sim import sim_powerlaw

    params = cz_sim_params_ap
    times = cz_times(params)

    grid = np.zeros((n_rows, n_cols, len(times)))

    idx = 0
    for i in range(n_rows):
        for j in range(n_cols):

            exp = exponents[idx]

            signal = sim_powerlaw(
                params["n_seconds"],
                params["s_rate"],
                exponent=exp,
                f_range=[params["high_pass_filter"], params["low_pass_filter"]]
            )

            grid[i, j, :] = signal
            idx += 1

    return grid, times

# %% [markdown]
# #### Testing the function - 4 electrodes, 2x2 cluster, aperiodic noise only, exponent = -1 for each
#
# Aim:
# - Generate 4 electrode signals
# - Each electrode signal should have an exponent of -1

# %% [markdown]
# #### Averaging the Time Series together
#
# - Compute and plot the average time series for the 4 signals
# - Compute and plot the PSD
# - Fit the Spectral Model and see what the exponent is

# %%
# Generate 2x2 cluster
exponents = [-1, -1, -1, -1]
grid_signals, times = generate_2D_electrodes_ap(2, 2, exponents)

# %% [markdown]
# ##### Plot time series

# %%
n_rows, n_cols, _ = grid_signals.shape

for i in range(n_rows):
    for j in range(n_cols):
        fig, ax = plt.subplots()

        signal = grid_signals[i, j]

        plot_time_series(times, signal, ax=ax)
        ax.set_title(f"Electrode ({i},{j})")

        plt.show()

# %% [markdown]
# ##### Average time series

# %%
# Average across rows and columns
avg_signal = np.mean(grid_signals, axis=(0, 1))

# Plot
plot_time_series(times, avg_signal, title="Average Signal")

# %% [markdown]
# ##### Plot PSD

# %%
# Compute and plot the PSD, in the frequency domain
params = cz_sim_params_ap.copy()
welch_dict = welch_params(params)

fig, ax = plt.subplots()

freqs, powers = compute_spectrum_welch(avg_signal, fs=params["s_rate"], **welch_dict)
plot_spectra(freqs, powers, log_powers=True, ax=ax)

ax.set_xlim(-1, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot Spectral Model

# %%
# Plot Spectral Model and look at the exponent output 
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, powers, freq_range)
# Out:
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -1.2411, 0.9807
#
#                          Peak Parameters ('gaussian' mode) 4 peaks found
#                                 CF:   6.51, PW:   0.11, BW:   1.70
#                                 CF:  13.30, PW:   0.11, BW:   5.99
#                                 CF:  24.30, PW:   0.10, BW:   2.57
#                                 CF:  36.30, PW:   0.16, BW:   2.17
#
#                                           Model metrics:
#                                      error (mae) is 0.0272
#                                   gof (rsquared) is 0.9876
#
# ==================================================================================================

# %% [markdown]
# #### Averaging the PSD together
#
# - Compute and plot the time series for the 4 signals
# - Compute and plot the average PSD
# - Fit the Spectral Model and see what the exponent is

# %%
# Generate 2x2 cluster
exponents = [-1, -1, -1, -1]
grid_signals, times = generate_2D_electrodes_ap(2, 2, exponents)

# %% [markdown]
# ##### Plot time series

# %%
n_rows, n_cols, _ = grid_signals.shape

for i in range(n_rows):
    for j in range(n_cols):
        fig, ax = plt.subplots()

        signal = grid_signals[i, j]

        plot_time_series(times, signal, ax=ax)
        ax.set_title(f"Electrode ({i},{j})")

        plt.show()

# %% [markdown]
# #### Plot PSDs

# %%
# Compute and plot the individual PSDs, in the frequency domain
psds = {}

params = cz_sim_params_ap.copy()
welch_dict = welch_params(params)

n_rows, n_cols, _ = grid_signals.shape

for i in range(n_rows):
    for j in range(n_cols):
        
        fig, ax = plt.subplots()

        signal = grid_signals[i, j]

        freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)

        name = f"electrode_{i*n_cols + j + 1}"

        psds[name] = (freqs, powers)

        plot_spectra(freqs, powers, log_powers=True, ax=ax)

        ax.set_title(name)
        ax.set_xlim(-1, 55)
        ax.set_ylim(-4, 0)

        plt.show()

# %% [markdown]
# ##### Average PSD

# %%
power_array = np.array([powers for freqs, powers in psds.values()])
avg_powers = np.mean(power_array, axis=0)

freqs = list(psds.values())[0][0]

fig, ax = plt.subplots()

plot_spectra(freqs, avg_powers, log_powers=True, ax=ax)

ax.set_title("Average PSD")
ax.set_xlim(0, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot Spectral Model

# %%
# Plot Spectral Model and look at the exponent output 
fm = SpectralModel(**spectral_model_params)
freq_range = freq_range

fm.report(freqs, powers, freq_range)
# Out:
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6436, 0.9846
#
#                          Peak Parameters ('gaussian' mode) 6 peaks found
#                                 CF:   8.71, PW:   0.14, BW:   2.58
#                                 CF:  14.36, PW:   0.19, BW:   1.46
#                                 CF:  24.42, PW:   0.11, BW:   0.65
#                                 CF:  26.26, PW:   0.15, BW:   1.46
#                                 CF:  28.42, PW:   0.24, BW:   0.69
#                                 CF:  32.80, PW:   0.13, BW:   3.18
#
#                                           Model metrics:
#                                      error (mae) is 0.0315
#                                   gof (rsquared) is 0.9839
#
# ==================================================================================================

# %% [markdown]
# #### Averaging the Spectral Models together
#
# - Compute and plot the time series for the 4 signals
# - Compute and plot the PSDs for the 4 signals
# - Fit the Spectral Models for each signal and calculate the average exponent

# %%
# Generate 2x2 cluster
exponents = [-1, -1, -1, -1]
grid_signals, times = generate_2D_electrodes_ap(2, 2, exponents)

# %% [markdown]
# ##### Plot the time series

# %%
n_rows, n_cols, _ = grid_signals.shape

for i in range(n_rows):
    for j in range(n_cols):
        fig, ax = plt.subplots()

        signal = grid_signals[i, j]

        plot_time_series(times, signal, ax=ax)
        ax.set_title(f"Electrode ({i},{j})")

        plt.show()

# %% [markdown]
# ##### Plot the individual PSDs

# %%
# Compute and plot the individual PSDs, in the frequency domain
psds = {}

params = cz_sim_params_ap.copy()
welch_dict = welch_params(params)

n_rows, n_cols, _ = grid_signals.shape

for i in range(n_rows):
    for j in range(n_cols):
        
        fig, ax = plt.subplots()

        signal = grid_signals[i, j]

        freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)

        name = f"electrode_{i*n_cols + j + 1}"

        psds[name] = (freqs, powers)

        plot_spectra(freqs, powers, log_powers=True, ax=ax)

        ax.set_title(name)
        ax.set_xlim(-1, 55)
        ax.set_ylim(-4, 0)

        plt.show()

# %% [markdown]
# ##### Plot the indiviudal Spectral Models

# %%
spectral_models = {}

for name, (freqs, powers) in psds.items():

    # Fit model
    fm = SpectralModel(**spectral_model_params)
    freq_range = freq_range
    fm.report(freqs, powers, freq_range)

    spectral_models[name] = fm
# Out:
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6816, 0.9451
#
#                          Peak Parameters ('gaussian' mode) 3 peaks found
#                                 CF:   4.70, PW:   0.16, BW:   2.93
#                                 CF:  15.48, PW:   0.12, BW:   0.68
#                                 CF:  18.61, PW:   0.13, BW:   4.37
#
#                                           Model metrics:
#                                      error (mae) is 0.0274
#                                   gof (rsquared) is 0.9904
#
# ==================================================================================================
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6234, 1.0129
#
#                          Peak Parameters ('gaussian' mode) 6 peaks found
#                                 CF:   8.51, PW:   0.11, BW:   1.55
#                                 CF:  15.90, PW:   0.08, BW:   2.03
#                                 CF:  18.54, PW:   0.08, BW:   0.70
#                                 CF:  22.34, PW:   0.12, BW:   0.65
#                                 CF:  24.14, PW:   0.10, BW:   1.63
#                                 CF:  28.57, PW:   0.12, BW:   2.95
#
#                                           Model metrics:
#                                      error (mae) is 0.0276
#                                   gof (rsquared) is 0.9854
#
# ==================================================================================================
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.7428, 0.8763
#
#                          Peak Parameters ('gaussian' mode) 3 peaks found
#                                 CF:   2.60, PW:   0.15, BW:   1.10
#                                 CF:   5.56, PW:   0.11, BW:   1.68
#                                 CF:  22.05, PW:   0.19, BW:   1.93
#
#                                           Model metrics:
#                                      error (mae) is 0.0302
#                                   gof (rsquared) is 0.9837
#
# ==================================================================================================
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.5243, 1.0681
#
#                          Peak Parameters ('gaussian' mode) 3 peaks found
#                                 CF:  23.78, PW:   0.18, BW:   1.33
#                                 CF:  28.49, PW:   0.13, BW:   3.94
#                                 CF:  37.12, PW:   0.19, BW:   1.76
#
#                                           Model metrics:
#                                      error (mae) is 0.0330
#                                   gof (rsquared) is 0.9813
#
# ==================================================================================================

# %% [markdown]
# ##### Average the exponent output

# %%
exponents = []

for name, fm in spectral_models.items():
    exponent = fm.get_params('aperiodic', 'exponent')
    exponents.append(exponent)
    print(f"{name}: {exponent:.3f}")

avg_exponent = np.mean(exponents)

print(f"Average exponent: {avg_exponent:.3f}")
# Out:
# electrode_1: 0.945
# electrode_2: 1.013
# electrode_3: 0.876
# electrode_4: 1.068
# Average exponent: 0.976

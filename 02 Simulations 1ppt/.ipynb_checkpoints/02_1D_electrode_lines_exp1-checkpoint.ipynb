# %% [markdown]
# ### Simulating 1D lines of electrodes
#
# - Simulating 3 electrodes where the exponent is -1 for each
# - Explore what happens to the output exponent when you average:
#     - The time series
#     - The PSDs
#     - The exponent outputs from the model fit
# - Simulate this for both aperiodic and full electrode signals

# %% [markdown]
# #### Imports

# %%
# Imports required for functionality 
import numpy as np
import matplotlib.pyplot as plt

from dissertation_simulations.cz_signal_simulations import generate_cz_signal_ap
from dissertation_simulations.cz_signal_simulations import generate_cz_signal_full

from dissertation_simulations.params import cz_sim_params_ap
from dissertation_simulations.params import cz_sim_params_full
from dissertation_simulations.params import welch_params
from dissertation_simulations.params import spectral_model_params
from dissertation_simulations.params import freq_range

from neurodsp.plts import plot_time_series
from neurodsp.spectral import compute_spectrum_welch

from specparam import SpectralModel
from specparam.plts import plot_spectra

from dissertation_simulations.generate_1D_electrodes import generate_1D_electrodes_ap
from dissertation_simulations.generate_1D_electrodes import generate_1D_electrodes_full

# %% [markdown]
# #### Testing the function - 3 electrodes, aperiodic noise only, exponent = -1 for each
#
# Aim:
# - Generate 3 electrode signals
# - Each electrode signal should have an exponent of -1

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Averaging the Time Series together
#
# - Compute and plot the average time series for the 3 signals
# - Compute and plot the PSD
# - Fit the Spectral Model and see what the exponent is

# %%
# Convert to array (shape: n_electrodes × n_timepoints)
signal_array = np.array(list(signals.values()))

# Average across electrodes
avg_signal = np.mean(signal_array, axis=0)

# Plot average time series
plot_time_series(times, avg_signal)

# %% [markdown]
# ##### Plot the PSD

# %%
# Compute and plot the PSD, in the frequency domain
params = cz_sim_params_ap.copy()
welch_dict = welch_params(params)

fig, ax = plt.subplots()

freqs, powers = compute_spectrum_welch(avg_signal, fs=params["s_rate"], **welch_dict)
plot_spectra(freqs, powers, log_powers=True, ax=ax)

ax.set_xlim(-1, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot Spectral Model

# %%
# Plot Spectral Model and look at the exponent output 
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, powers, freq_range)
# Out:
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -1.1373, 0.9547
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  17.50, PW:   0.20, BW:   3.36
#
#                                           Model metrics:
#                                      error (mae) is 0.0453
#                                   gof (rsquared) is 0.9677
#
# ==================================================================================================

# %% [markdown]
# Exponent is close to 1 - to be expected

# %% [markdown]
# #### Averaging the PSD together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the average PSD
# - Fit the Spectral Model and see what the exponent is

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot the PSD for each

# %%
psds = {}

welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Average the PSDs

# %%
power_array = np.array([powers for freqs, powers in psds.values()])
avg_powers = np.mean(power_array, axis=0)

freqs = list(psds.values())[0][0]

fig, ax = plt.subplots()

plot_spectra(freqs, avg_powers, log_powers=True, ax=ax)

ax.set_title("Average PSD")
ax.set_xlim(0, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot Spectral Model

# %%
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6124, 0.9949
#
#                          Peak Parameters ('gaussian' mode) 7 peaks found
#                                 CF:   4.19, PW:   0.08, BW:   2.07
#                                 CF:  10.77, PW:   0.08, BW:   1.68
#                                 CF:  15.35, PW:   0.06, BW:   1.41
#                                 CF:  18.47, PW:   0.05, BW:   0.55
#                                 CF:  22.49, PW:   0.05, BW:   2.25
#                                 CF:  28.00, PW:   0.05, BW:   4.18
#                                 CF:  32.75, PW:   0.07, BW:   1.92
#
#                                           Model metrics:
#                                      error (mae) is 0.0107
#                                   gof (rsquared) is 0.9979
#
# ==================================================================================================

# %% [markdown]
# Exponent is close to 1 - to be expected

# %% [markdown]
# #### Averaging the Spectral Models together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the PSDs for the 3 signals
# - Fit the Spectral Models for each signal and calculate the average exponent

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot the PSD for each

# %%
psds = {}

welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Plot the Spectral Models for each

# %%
spectral_models = {}

for name, (freqs, powers) in psds.items():

    # Fit model
    fm = SpectralModel()
    freq_range = freq_range
    fm.report(freqs, powers, freq_range)

    spectral_models[name] = fm
# Out:
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.7777, 0.8705
#
#                          Peak Parameters ('gaussian' mode) 7 peaks found
#                                 CF:   4.39, PW:   0.15, BW:   1.90
#                                 CF:   6.87, PW:   0.16, BW:   1.75
#                                 CF:  12.21, PW:   0.12, BW:   2.27
#                                 CF:  17.26, PW:   0.13, BW:   3.81
#                                 CF:  22.84, PW:   0.14, BW:   1.62
#                                 CF:  27.28, PW:   0.09, BW:   0.53
#                                 CF:  30.78, PW:   0.13, BW:   1.55
#
#                                           Model metrics:
#                                      error (mae) is 0.0239
#                                   gof (rsquared) is 0.9874
#
# ==================================================================================================
#
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.6479, 0.9811
#
#                          Peak Parameters ('gaussian' mode) 4 peaks found
#                                 CF:   4.73, PW:   0.11, BW:   1.17
#                                 CF:   8.49, PW:   0.18, BW:   0.66
#                                 CF:  33.30, PW:   0.11, BW:   0.57
#                                 CF:  37.54, PW:   0.11, BW:   5.06
#
#                                           Model metrics:
#                                      error (mae) is 0.0323
#                                   gof (rsquared) is 0.9848
#
# ==================================================================================================
#
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.5602, 1.0930
#
#                          Peak Parameters ('gaussian' mode) 8 peaks found
#                                 CF:   2.64, PW:   0.09, BW:   1.30
#                                 CF:   6.86, PW:   0.11, BW:   1.68
#                                 CF:  11.32, PW:   0.11, BW:   1.60
#                                 CF:  16.21, PW:   0.12, BW:   1.29
#                                 CF:  21.83, PW:   0.16, BW:   2.37
#                                 CF:  26.68, PW:   0.08, BW:   1.62
#                                 CF:  32.19, PW:   0.10, BW:   0.95
#                                 CF:  38.61, PW:   0.17, BW:   2.93
#
#                                           Model metrics:
#                                      error (mae) is 0.0211
#                                   gof (rsquared) is 0.9939
#
# ==================================================================================================

# %% [markdown]
# ##### Calculate average exponent value

# %%
exponents = []

for name, fm in spectral_models.items():
    exponent = fm.get_params('aperiodic', 'exponent')
    exponents.append(exponent)
    print(f"{name}: {exponent:.3f}")

avg_exponent = np.mean(exponents)

print(f"Average exponent: {avg_exponent:.3f}")
# Out:
# electrode_1: 0.870
# electrode_2: 0.981
# electrode_3: 1.093
# Average exponent: 0.982

# %% [markdown]
# #### Testing the function - 3 electrodes, aperiodic and periodic noise, exponent = -1 for each
#
# Aim:
# - Generate 3 electrode signals
# - Each electrode signal should have an exponent of -1

# %%
exponents = [-1, -1, -1]
signals, params_list, times = generate_1D_electrodes_full(3, exponents)

# %% [markdown]
# ##### Plot the time series of the 3 electrode signals

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Averaging the Time Series together
#
# - Compute and plot the average time series for the 3 signals
# - Compute and plot the PSD
# - Fit the Spectral Model and see what the exponent is

# %%
# Convert to array (shape: n_electrodes × n_timepoints)
signal_array = np.array(list(signals.values()))

# Average across electrodes
avg_signal = np.mean(signal_array, axis=0)

# Plot average time series
plot_time_series(times, avg_signal)

# %% [markdown]
# ##### Plot the PSD

# %%
# Compute and plot the PSD, in the frequency domain
params = cz_sim_params_full.copy()
welch_dict = welch_params(params)

fig, ax = plt.subplots()

freqs, powers = compute_spectrum_welch(avg_signal, fs=params["s_rate"], **welch_dict)
plot_spectra(freqs, powers, log_powers=True, ax=ax)

ax.set_xlim(-1, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot the Spectral Model

# %%
# Plot Spectral Model and look at the exponent output 
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, powers, freq_range)
# Out:
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -1.3636, 0.9960
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.03, PW:   1.99, BW:   1.91
#
#                                           Model metrics:
#                                      error (mae) is 0.0610
#                                   gof (rsquared) is 0.9813
#
# ==================================================================================================

# %% [markdown]
# Exponent is close to 1 - to be expected

# %% [markdown]
# #### Averaging the PSD together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the average PSD
# - Fit the Spectral Model and see what the exponent is

# %%
exponents = [-1, -1, -1, -1]
signals, params_list, times = generate_1D_electrodes_full(4, exponents)

# %% [markdown]
# ##### Plot the time series for each electrode

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot indidivual PSDs

# %%
psds = {}

params = cz_sim_params_full.copy()
welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Plot average PSD

# %%
power_array = np.array([powers for freqs, powers in psds.values()])
avg_powers = np.mean(power_array, axis=0)

freqs = list(psds.values())[0][0]

fig, ax = plt.subplots()

plot_spectra(freqs, avg_powers, log_powers=True, ax=ax)

ax.set_title("Average PSD")
ax.set_xlim(0, 55)
ax.set_ylim(-4, 0)

plt.show()

# %% [markdown]
# ##### Plot the Spectral Model

# %%
# Plot Spectral Model and look at the exponent output 
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.8911, 0.9918
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.04, PW:   1.48, BW:   1.74
#
#                                           Model metrics:
#                                      error (mae) is 0.0395
#                                   gof (rsquared) is 0.9875
#
# ==================================================================================================

# %% [markdown]
# Exponet close to 1 - to be expected

# %% [markdown]
# #### Averaging the Spectral Models together
#
# - Compute and plot the time series for the 3 signals
# - Compute and plot the PSDs for the 3 signals
# - Fit the Spectral Models for each signal and calculate the average exponent

# %%
exponents = [-1, -1, -1, -1]
signals, params_list, times = generate_1D_electrodes_full(4, exponents)

# %% [markdown]
# ##### Plot the Time Series for each electrode

# %%
fig, axes = plt.subplots(len(signals), 1, sharex=True)

for ax, (name, signal) in zip(axes, signals.items()):
    plot_time_series(times, signal, ax=ax)
    ax.set_title(name)

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot individual PSDs

# %%
psds = {}

params = cz_sim_params_full.copy()
welch_dict = welch_params(params)

for name, signal in signals.items():
    fig, ax = plt.subplots()
    freqs, powers = compute_spectrum_welch(signal, fs=params["s_rate"], **welch_dict)
    
    psds[name] = (freqs, powers)
    plot_spectra(freqs, powers, log_powers=True, ax=ax)

    ax.set_title(name)
    ax.set_xlim(-1, 55)
    ax.set_ylim(-4, 0)

    plt.show()

# %% [markdown]
# ##### Plot individual Spectral Models

# %%
spectral_models = {}

for name, (freqs, powers) in psds.items():

    # Fit model
    fm = SpectralModel()
    freq_range = freq_range
    fm.report(freqs, powers, freq_range)

    spectral_models[name] = fm
# Out:
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.8736, 1.0286
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.05, PW:   1.52, BW:   1.77
#
#                                           Model metrics:
#                                      error (mae) is 0.0617
#                                   gof (rsquared) is 0.9759
#
# ==================================================================================================
#
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.8815, 1.0065
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.01, PW:   1.46, BW:   1.84
#
#                                           Model metrics:
#                                      error (mae) is 0.0490
#                                   gof (rsquared) is 0.9836
#
# ==================================================================================================
#
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.8762, 1.0016
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.08, PW:   1.48, BW:   1.75
#
#                                           Model metrics:
#                                      error (mae) is 0.0554
#                                   gof (rsquared) is 0.9770
#
# ==================================================================================================
#
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.9115, 0.9802
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  10.00, PW:   1.47, BW:   1.87
#
#                                           Model metrics:
#                                      error (mae) is 0.0470
#                                   gof (rsquared) is 0.9836
#
# ==================================================================================================

# %% [markdown]
# ##### Average Spectral Model exponent

# %%
exponents = []

for name, fm in spectral_models.items():
    exponent = fm.get_params('aperiodic', 'exponent')
    exponents.append(exponent)
    print(f"{name}: {exponent:.3f}")

avg_exponent = np.mean(exponents)

print(f"Average exponent: {avg_exponent:.3f}")
# Out:
# electrode_1: 1.029
# electrode_2: 1.006
# electrode_3: 1.002
# electrode_4: 0.980
# Average exponent: 1.004

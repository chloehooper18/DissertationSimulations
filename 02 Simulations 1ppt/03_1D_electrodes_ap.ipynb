# %% [markdown]
# ### Simulating 1D lines of electrodes
#
# - Simulating electrodes where the exponent is a random value between -1 and -2
# - Average the PSD and plot the Spectral Model
# - Simulate this for both aperiodi signals only

# %% [markdown]
# ##### Imports

# %%
# Imports required for functionality 
import numpy as np
import matplotlib.pyplot as plt

from dissertation_simulations.params import cz_sim_params_ap
from dissertation_simulations.generate_1D_electrodes import generate_1D_electrodes_ap
from dissertation_simulations.psd import avg_psd
from dissertation_simulations.exponents import gen_exponents

from specparam import SpectralModel
from dissertation_simulations.params import freq_range

# %% [markdown]
# #### 3 electrodes
# - Simulate 3 electrodes with random exponents between -1 and -2
# - Calculate the average PSD and plot the spectral model

# %%
# Load in copy of parameters
params = cz_sim_params_ap.copy()

# Generate random exponents
exponents = gen_exponents(3, (-2, -1))
print(exponents)

# Generate 1D electrode array
signals, params_list, times = generate_1D_electrodes_ap(3, exponents)

# Compute and plot average PSD
psds, avg_powers, freqs = avg_psd(signals, params)

# Fit and plot Spectral model
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# [-1.179732043372732, -1.111203253708796, -1.162124502123385]
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.4284, 1.2160
#
#                          Peak Parameters ('gaussian' mode) 6 peaks found
#                                 CF:  10.26, PW:   0.08, BW:   2.25
#                                 CF:  15.10, PW:   0.08, BW:   3.00
#                                 CF:  24.10, PW:   0.07, BW:   1.39
#                                 CF:  27.40, PW:   0.08, BW:   3.39
#                                 CF:  34.24, PW:   0.06, BW:   0.58
#                                 CF:  38.28, PW:   0.06, BW:   5.01
#
#                                           Model metrics:
#                                      error (mae) is 0.0173
#                                   gof (rsquared) is 0.9969
#
# ==================================================================================================

# %% [markdown]
# #### 6 electrodes
# - Simulate 6 electrodes with random exponents between -1 and -2
# - Calculate the average PSD and plot the spectral model

# %%
# Load in copy of parameters
params = cz_sim_params_ap.copy()

# Generate random exponents
exponents = gen_exponents(6, (-2, -1))
print(exponents)

# Generate 1D electrode array
signals, params_list, times = generate_1D_electrodes_ap(6, exponents)

# Compute and plot average PSD
psds, avg_powers, freqs = avg_psd(signals, params)

# Fit and plot Spectral model
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# [-1.0114815507165473, -1.2653384965068892, -1.4986306206276585, -1.4854099217994565, -1.7149488433405984, -1.4459015220047768]
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.2981, 1.3922
#
#                          Peak Parameters ('gaussian' mode) 8 peaks found
#                                 CF:   3.43, PW:   0.07, BW:   0.59
#                                 CF:   5.82, PW:   0.05, BW:   1.14
#                                 CF:   7.69, PW:   0.05, BW:   1.13
#                                 CF:  13.87, PW:   0.05, BW:   3.50
#                                 CF:  17.53, PW:   0.05, BW:   1.64
#                                 CF:  25.10, PW:   0.09, BW:   2.23
#                                 CF:  28.06, PW:   0.07, BW:   1.61
#                                 CF:  34.21, PW:   0.06, BW:   1.85
#
#                                           Model metrics:
#                                      error (mae) is 0.0083
#                                   gof (rsquared) is 0.9992
#
# ==================================================================================================

# %% [markdown]
# #### 9 electrodes
# - Simulate 9 electrodes with random exponents between -1 and -2
# - Calculate the average PSD and plot the spectral model

# %%
# Load in copy of parameters
params = cz_sim_params_ap.copy()

# Generate random exponents
exponents = gen_exponents(9, (-2, -1))
print(exponents)

# Generate 1D electrode array
signals, params_list, times = generate_1D_electrodes_ap(9, exponents)

# Compute and plot average PSD
psds, avg_powers, freqs = avg_psd(signals, params)

# Fit and plot Spectral model
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# [-1.996161062111629, -1.6782858570319794, -1.8742298404722733, -1.4112384523946537, -1.596559259813295, -1.771026545808049, -1.5127007255799447, -1.1824849185553075, -1.6798718232525278]
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.2380, 1.5253
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:   3.22, PW:   0.07, BW:   6.85
#
#                                           Model metrics:
#                                      error (mae) is 0.0184
#                                   gof (rsquared) is 0.9980
#
# ==================================================================================================

# %% [markdown]
# #### 12 electrodes
# - Simulate 12 electrodes with random exponents between -1 and -2
# - Calculate the average PSD and plot the spectral model

# %%
# Load in copy of parameters
params = cz_sim_params_ap.copy()

# Generate random exponents
exponents = gen_exponents(12, (-2, -1))
print(exponents)

# Generate 1D electrode array
signals, params_list, times = generate_1D_electrodes_ap(12, exponents)

# Compute and plot average PSD
psds, avg_powers, freqs = avg_psd(signals, params)

# Fit and plot Spectral model
fm = SpectralModel()
freq_range = freq_range

fm.report(freqs, avg_powers, freq_range)
# Out:
# [-1.57826289240016, -1.0599010848426937, -1.3074175199616687, -1.0506084628964811, -1.5590118604933738, -1.9187326980099253, -1.092757030872454, -1.8972973467788148, -1.9152833269519645, -1.1548820689564625, -1.5622328500312888, -1.2023193353954418]
# WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 1.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#                Model was fit to the 2-40 Hz frequency range with 1.00 Hz resolution
#
#                                Aperiodic Parameters ('fixed' mode)
#                                         (offset, exponent)
#                                          -0.2919, 1.3777
#
#                          Peak Parameters ('gaussian' mode) 0 peaks found
#
#                                           Model metrics:
#                                      error (mae) is 0.0149
#                                   gof (rsquared) is 0.9980
#
# ==================================================================================================

# %% [markdown]
# ### Averaging Time Series with more realistic 2D electrode matrices

# %%
# Imports for functionality 
from dissertation_simulations.exponents import generate_2D_exponent_matrix, generate_spatial_exponent_matrix

# %%
exp_matrix = generate_2D_exponent_matrix(grid_shape=(3, 3), exp_range=(-1, -2), gradient_axis="cols")

exp_matrix
# Out:
# array([[-1. , -1.5, -2. ],
#        [-1. , -1.5, -2. ],
#        [-1. , -1.5, -2. ]])

# %%
exp_matrix = generate_2D_exponent_matrix(grid_shape=(5, 5), exp_range=(-1, -2), gradient_axis="cols")

exp_matrix
# Out:
# array([[-1.  , -1.25, -1.5 , -1.75, -2.  ],
#        [-1.  , -1.25, -1.5 , -1.75, -2.  ],
#        [-1.  , -1.25, -1.5 , -1.75, -2.  ],
#        [-1.  , -1.25, -1.5 , -1.75, -2.  ],
#        [-1.  , -1.25, -1.5 , -1.75, -2.  ]])

# %%
exp_matrix = generate_spatial_exponent_matrix(grid_shape=(3, 3), exp_min=-2, exp_max=-0.5, pattern="diagonal")

exp_matrix
# Out:
# array([[-2.   , -1.625, -1.25 ],
#        [-1.625, -1.25 , -0.875],
#        [-1.25 , -0.875, -0.5  ]])

# %%
exp_matrix = generate_spatial_exponent_matrix(grid_shape=(3, 3), exp_min=-2, exp_max=-0.5, pattern="radial")

exp_matrix
# Out:
# array([[-0.5       , -0.93933983, -0.5       ],
#        [-0.93933983, -2.        , -0.93933983],
#        [-0.5       , -0.93933983, -0.5       ]])

# %%
exp_matrix = generate_2D_exponent_matrix(grid_shape=(1, 3), exp_range=(-1, -2), gradient_axis="cols")

exp_matrix
# Out:
# array([[-1. , -1.5, -2. ]])

# %%
exp_matrix = generate_2D_exponent_matrix(grid_shape=(1, 9), exp_range=(-1, -2), gradient_axis="cols")

exp_matrix
# Out:
# array([[-1.   , -1.125, -1.25 , -1.375, -1.5  , -1.625, -1.75 , -1.875,
#         -2.   ]])

# %%
exp_matrix = generate_spatial_exponent_matrix(grid_shape=(1, 9), exp_min=-2, exp_max=-0.5, pattern="radial")

exp_matrix
# Out:
# array([[-0.5       , -1.09466991, -1.57256112, -1.88854877, -2.        ,
#         -1.88854877, -1.57256112, -1.09466991, -0.5       ]])

# %% [markdown]
# ### Running sweep functions and saving the plot
#
# - call functions
# - save plot

# %%
# imports for functionality 
from dissertation_simulations.time_series import sweep_electrodes_ts_2D
from dissertation_simulations.psd import sweep_electrodes_psd_2D
from dissertation_simulations.spec_mod import sweep_electrodes_specmod_2D
from dissertation_simulations.exponents import generate_2D_exponent_matrix

# %%
grid_range = [(n, n) for n in range(2, 9)]

exponent_matrices = [generate_2D_exponent_matrix
                     (grid_shape=grid_shape, exp_range=(-2, -1), gradient_axis="cols")
    for grid_shape in grid_range]

electrodes, means, stds, errors, fig = sweep_electrodes_ts_2D(grid_range=grid_range, exponent_matrices=exponent_matrices, 
                                                              n_repeats=100)
fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\fig01_ts_exp2.5.png", dpi=300)

# %%
grid_range = [(n, n) for n in range(2, 9)]

exponent_matrices = [generate_2D_exponent_matrix
                     (grid_shape=grid_shape, exp_range=(-2, -1), gradient_axis="cols")
    for grid_shape in grid_range]

electrodes, means, stds, errors, fig = sweep_electrodes_psd_2D(grid_range=grid_range, exponent_matrices=exponent_matrices, 
                                                              n_repeats=100)
fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\fig02_psd_exp2.5.png", dpi=300)

# %%
grid_range = [(n, n) for n in range(2, 9)]

exponent_matrices = [generate_2D_exponent_matrix
                     (grid_shape=grid_shape, exp_range=(-2, -1), gradient_axis="cols")
    for grid_shape in grid_range]

electrodes, means, stds, errors, fig = sweep_electrodes_specmod_2D(grid_range=grid_range, exponent_matrices=exponent_matrices, 
                                                              n_repeats=100)
fig.savefig(r"C:\Users\chloe\DissertationSimulations\Figures\2D electrodes\fig03_specmod_exp2.5.png", dpi=300)
